# %% [markdown]
# # AI Finance Agent  (LlamaIndex | LlaMa-3.1)
#
# ## Table of Contents
#
# 1. **Load LLM (LlaMa-3)**
# 2. **Define Finance Tools**
# 3. **Create Finance Agent (LLM + Tools)**
#
# ## Finance Agent Functionalities
#
# * **Stock Company Basic Information**
#     * Address, Industry, Sector, business summary, website, etc.
#     * Top Company Officers
# * **Stock Financials**
#     * Market Cap, current price, ebitda, total debt, total revenue, debt-to-equity, P/E ratio, operating margins, ebitda margins, operating cashflow, free cashflow, etc.
# * **Stock Dividend & Earnings Dates**
# * **Information about Mutual Fund Holders**
# * **Information about Institutional Holders**
# * **Stock Splits History**
# * **Stock Ratings Upgrades & Downgrades by various Companies**
# * **News Articles about Stock**

# %%
import dotenv
import os

dotenv.load_dotenv('dotenv')


groq_api_key = os.environ["GROQ_API_KEY"]

# %%
import yfinance as yf

yf.__version__
# Out:
# '0.2.41'

# %% [markdown]
# ## 1. Load LLM
#
# * Login to **https://console.groq.com** and create API Key.
#
# ### Groq Models
#
# <img src="GroqModels.jpg" width=800/>
#
# #### LlamaIndex Groq Package
#
# * **pip install llama-index-llms-groq**

# %%
# !pip install --upgrade llama_index langchain
# Out:
# Requirement already satisfied: llama_index in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (0.11.8)
# Collecting llama_index
#   Downloading llama_index-0.11.9-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: langchain in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (0.2.16)
# Collecting langchain
#   Downloading langchain-0.3.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: llama-index-agent-openai<0.4.0,>=0.3.1 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama_index) (0.3.1)
# Requirement already satisfied: llama-index-cli<0.4.0,>=0.3.1 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama_index) (0.3.1)
# Collecting llama-index-core<0.12.0,>=0.11.9 (from llama_index)
#   Downloading llama_index_core-0.11.9-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: llama-index-embeddings-openai<0.3.0,>=0.2.4 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama_index) (0.2.4)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.3.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama_index) (0.3.0)
# Requirement already satisfied: llama-index-legacy<0.10.0,>=0.9.48 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama_index) (0.9.48.post3)
# Requirement already satisfied: llama-index-llms-openai<0.3.0,>=0.2.3 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama_index) (0.2.3)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.3.0,>=0.2.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama_index) (0.2.0)
# Requirement already satisfied: llama-index-program-openai<0.3.0,>=0.2.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama_index) (0.2.0)
# Requirement already satisfied: llama-index-question-gen-openai<0.3.0,>=0.2.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama_index) (0.2.0)
# Requirement already satisfied: llama-index-readers-file<0.3.0,>=0.2.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama_index) (0.2.1)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.3.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama_index) (0.3.0)
# Requirement already satisfied: nltk>3.8.1 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama_index) (3.9.1)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from langchain) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from langchain) (3.10.0)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from langchain) (4.0.2)
# Collecting langchain-core<0.4.0,>=0.3.0 (from langchain)
#   Downloading langchain_core-0.3.0-py3-none-any.whl.metadata (6.2 kB)
# Collecting langchain-text-splitters<0.4.0,>=0.3.0 (from langchain)
#   Downloading langchain_text_splitters-0.3.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from langchain) (0.1.118)
# Requirement already satisfied: numpy<2,>=1 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from langchain) (1.24.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from langchain) (2.8.2)
# Requirement already satisfied: requests<3,>=2 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from langchain) (8.2.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.3.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (5.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from langchain-core<0.4.0,>=0.3.0->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from langchain-core<0.4.0,>=0.3.0->langchain) (23.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from langchain-core<0.4.0,>=0.3.0->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.6)
# Requirement already satisfied: openai>=1.14.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-agent-openai<0.4.0,>=0.3.1->llama_index) (1.44.1)
# Requirement already satisfied: dataclasses-json in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (0.5.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (2024.6.1)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (3.3)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (10.0.0)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (4.66.1)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (0.8.0)
# Requirement already satisfied: wrapt in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (1.14.1)
# Requirement already satisfied: llama-cloud>=0.0.11 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-indices-managed-llama-cloud>=0.3.0->llama_index) (0.0.17)
# Requirement already satisfied: pandas in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-legacy<0.10.0,>=0.9.48->llama_index) (2.2.2)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-readers-file<0.3.0,>=0.2.0->llama_index) (4.12.3)
# Requirement already satisfied: pypdf<5.0.0,>=4.0.1 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-readers-file<0.3.0,>=0.2.0->llama_index) (4.3.0)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-readers-file<0.3.0,>=0.2.0->llama_index) (0.0.26)
# Requirement already satisfied: llama-parse>=0.5.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-readers-llama-parse>=0.3.0->llama_index) (0.5.5)
# Requirement already satisfied: click in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from nltk>3.8.1->llama_index) (8.1.7)
# Requirement already satisfied: joblib in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from nltk>3.8.1->llama_index) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from nltk>3.8.1->llama_index) (2023.5.5)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2->langchain) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2->langchain) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2->langchain) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (2.0.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.3.0,>=0.2.0->llama_index) (2.5)
# Requirement already satisfied: anyio in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (3.6.2)
# Requirement already satisfied: httpcore==1.* in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.0.5)
# Requirement already satisfied: sniffio in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.0->langchain) (2.3)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from openai>=1.14.0->llama-index-agent-openai<0.4.0,>=0.3.1->llama_index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from openai>=1.14.0->llama-index-agent-openai<0.4.0,>=0.3.1->llama_index) (0.5.0)
# Requirement already satisfied: colorama in c:\users\serkan polat\appdata\roaming\python\python310\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core<0.12.0,>=0.11.9->llama_index) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.9->llama_index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.3.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.9->llama_index) (3.19.0)
# Requirement already satisfied: marshmallow-enum<2.0.0,>=1.5.1 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.9->llama_index) (1.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\serkan polat\appdata\roaming\python\python310\site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama_index) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama_index) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama_index) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\serkan polat\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.2->pandas->llama-index-legacy<0.10.0,>=0.9.48->llama_index) (1.16.0)
# Downloading llama_index-0.11.9-py3-none-any.whl (6.8 kB)
# Downloading langchain-0.3.0-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    ------------------------------- -------- 0.8/1.0 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 2.5 MB/s eta 0:00:00
# Downloading langchain_core-0.3.0-py3-none-any.whl (405 kB)
# Downloading langchain_text_splitters-0.3.0-py3-none-any.whl (25 kB)
# Downloading llama_index_core-0.11.9-py3-none-any.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------------- -------------------------- 0.5/1.6 MB 3.3 MB/s eta 0:00:01
#    -------------------------- ------------- 1.0/1.6 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 2.4 MB/s eta 0:00:00
# Installing collected packages: llama-index-core, langchain-core, langchain-text-splitters, langchain, llama_index
#   Attempting uninstall: llama-index-core
#     Found existing installation: llama-index-core 0.11.8
#     Uninstalling llama-index-core-0.11.8:
#       Successfully uninstalled llama-index-core-0.11.8
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.2.39
#     Uninstalling langchain-core-0.2.39:
#       Successfully uninstalled langchain-core-0.2.39
#   Attempting uninstall: langchain-text-splitters
#     Found existing installation: langchain-text-splitters 0.2.2
#     Uninstalling langchain-text-splitters-0.2.2:
#       Successfully uninstalled langchain-text-splitters-0.2.2
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.2.16
#     Uninstalling langchain-0.2.16:
#       Successfully uninstalled langchain-0.2.16
#   Attempting uninstall: llama_index
#     Found existing installation: llama-index 0.11.8
#     Uninstalling llama-index-0.11.8:
#       Successfully uninstalled llama-index-0.11.8
# Successfully installed langchain-0.3.0 langchain-core-0.3.0 langchain-text-splitters-0.3.0 llama-index-core-0.11.9 llama_index-0.11.9
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Error parsing dependencies of keras: [Errno 2] No such file or directory: 'c:\\users\\serkan polat\\appdata\\local\\programs\\python\\python310\\lib\\site-packages\\keras-2.12.0.dist-info\\METADATA'
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-community 0.2.6 requires langchain<0.3.0,>=0.2.6, but you have langchain 0.3.0 which is incompatible.
# langchain-community 0.2.6 requires langchain-core<0.3.0,>=0.2.10, but you have langchain-core 0.3.0 which is incompatible.
# langchain-openai 0.1.17 requires langchain-core<0.3.0,>=0.2.20, but you have langchain-core 0.3.0 which is incompatible.

# %%
# !pip install --upgrade llama_index
# Out:
# Requirement already satisfied: llama_index in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (0.11.9)
# Requirement already satisfied: llama-index-agent-openai<0.4.0,>=0.3.1 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama_index) (0.3.1)
# Requirement already satisfied: llama-index-cli<0.4.0,>=0.3.1 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama_index) (0.3.1)
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.9 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama_index) (0.11.9)
# Requirement already satisfied: llama-index-embeddings-openai<0.3.0,>=0.2.4 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama_index) (0.2.4)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.3.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama_index) (0.3.0)
# Requirement already satisfied: llama-index-legacy<0.10.0,>=0.9.48 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama_index) (0.9.48.post3)
# Requirement already satisfied: llama-index-llms-openai<0.3.0,>=0.2.3 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama_index) (0.2.3)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.3.0,>=0.2.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama_index) (0.2.0)
# Requirement already satisfied: llama-index-program-openai<0.3.0,>=0.2.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama_index) (0.2.0)
# Requirement already satisfied: llama-index-question-gen-openai<0.3.0,>=0.2.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama_index) (0.2.0)
# Requirement already satisfied: llama-index-readers-file<0.3.0,>=0.2.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama_index) (0.2.1)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.3.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama_index) (0.3.0)
# Requirement already satisfied: nltk>3.8.1 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama_index) (3.9.1)
# Requirement already satisfied: openai>=1.14.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-agent-openai<0.4.0,>=0.3.1->llama_index) (1.44.1)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.9->llama_index) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (3.10.0)
# Requirement already satisfied: dataclasses-json in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (0.5.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (2024.6.1)
# Requirement already satisfied: httpx in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (3.3)
# Requirement already satisfied: numpy<2.0.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (1.24.3)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (10.0.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (2.8.2)
# Requirement already satisfied: requests>=2.31.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (2.31.0)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (8.2.3)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (4.66.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (0.8.0)
# Requirement already satisfied: wrapt in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (1.14.1)
# Requirement already satisfied: llama-cloud>=0.0.11 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-indices-managed-llama-cloud>=0.3.0->llama_index) (0.0.17)
# Requirement already satisfied: pandas in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-legacy<0.10.0,>=0.9.48->llama_index) (2.2.2)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-readers-file<0.3.0,>=0.2.0->llama_index) (4.12.3)
# Requirement already satisfied: pypdf<5.0.0,>=4.0.1 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-readers-file<0.3.0,>=0.2.0->llama_index) (4.3.0)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-readers-file<0.3.0,>=0.2.0->llama_index) (0.0.26)
# Requirement already satisfied: llama-parse>=0.5.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-readers-llama-parse>=0.3.0->llama_index) (0.5.5)
# Requirement already satisfied: click in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from nltk>3.8.1->llama_index) (8.1.7)
# Requirement already satisfied: joblib in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from nltk>3.8.1->llama_index) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from nltk>3.8.1->llama_index) (2023.5.5)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.9->llama_index) (2.3.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.9->llama_index) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.9->llama_index) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.9->llama_index) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.9->llama_index) (5.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.9->llama_index) (1.9.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.9->llama_index) (4.0.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.3.0,>=0.2.0->llama_index) (2.5)
# Requirement already satisfied: anyio in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.9->llama_index) (3.6.2)
# Requirement already satisfied: certifi in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.9->llama_index) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.9->llama_index) (1.0.5)
# Requirement already satisfied: idna in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.9->llama_index) (3.6)
# Requirement already satisfied: sniffio in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.9->llama_index) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.9->llama_index) (0.14.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from openai>=1.14.0->llama-index-agent-openai<0.4.0,>=0.3.1->llama_index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from openai>=1.14.0->llama-index-agent-openai<0.4.0,>=0.3.1->llama_index) (0.5.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.9->llama_index) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.9->llama_index) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.9->llama_index) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.9->llama_index) (2.1.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.9->llama_index) (2.0.2)
# Requirement already satisfied: colorama in c:\users\serkan polat\appdata\roaming\python\python310\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core<0.12.0,>=0.11.9->llama_index) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.9->llama_index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.3.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.9->llama_index) (3.19.0)
# Requirement already satisfied: marshmallow-enum<2.0.0,>=1.5.1 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.9->llama_index) (1.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\serkan polat\appdata\roaming\python\python310\site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama_index) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama_index) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama_index) (2023.3)
# Requirement already satisfied: packaging>=17.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from marshmallow<4.0.0,>=3.3.0->dataclasses-json->llama-index-core<0.12.0,>=0.11.9->llama_index) (23.2)
# Requirement already satisfied: six>=1.5 in c:\users\serkan polat\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.2->pandas->llama-index-legacy<0.10.0,>=0.9.48->llama_index) (1.16.0)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Error parsing dependencies of keras: [Errno 2] No such file or directory: 'c:\\users\\serkan polat\\appdata\\local\\programs\\python\\python310\\lib\\site-packages\\keras-2.12.0.dist-info\\METADATA'
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages)

# %%
# !pip install llama-index-llms-groq
# Out:
# Requirement already satisfied: llama-index-llms-groq in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (0.2.0)
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-llms-groq) (0.11.9)
# Requirement already satisfied: llama-index-llms-openai-like<0.3.0,>=0.2.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-llms-groq) (0.2.0)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (3.10.0)
# Requirement already satisfied: dataclasses-json in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (0.5.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (2024.6.1)
# Requirement already satisfied: httpx in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (3.3)
# Requirement already satisfied: nltk>3.8.1 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (3.9.1)
# Requirement already satisfied: numpy<2.0.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (1.24.3)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (10.0.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (2.8.2)
# Requirement already satisfied: requests>=2.31.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (2.31.0)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (8.2.3)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (4.66.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (0.8.0)
# Requirement already satisfied: wrapt in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (1.14.1)
# Requirement already satisfied: llama-index-llms-openai<0.3.0,>=0.2.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-llms-openai-like<0.3.0,>=0.2.0->llama-index-llms-groq) (0.2.3)
# Requirement already satisfied: transformers<5.0.0,>=4.37.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-llms-openai-like<0.3.0,>=0.2.0->llama-index-llms-groq) (4.44.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (2.3.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (5.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (1.9.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (4.0.2)
# Requirement already satisfied: llama-index-agent-openai<0.4.0,>=0.3.1 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-llms-openai<0.3.0,>=0.2.0->llama-index-llms-openai-like<0.3.0,>=0.2.0->llama-index-llms-groq) (0.3.1)
# Requirement already satisfied: openai<2.0.0,>=1.40.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from llama-index-llms-openai<0.3.0,>=0.2.0->llama-index-llms-openai-like<0.3.0,>=0.2.0->llama-index-llms-groq) (1.44.1)
# Requirement already satisfied: click in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (8.1.7)
# Requirement already satisfied: joblib in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (2023.5.5)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (2.0.2)
# Requirement already satisfied: colorama in c:\users\serkan polat\appdata\roaming\python\python310\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (0.4.6)
# Requirement already satisfied: filelock in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from transformers<5.0.0,>=4.37.0->llama-index-llms-openai-like<0.3.0,>=0.2.0->llama-index-llms-groq) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from transformers<5.0.0,>=4.37.0->llama-index-llms-openai-like<0.3.0,>=0.2.0->llama-index-llms-groq) (0.24.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from transformers<5.0.0,>=4.37.0->llama-index-llms-openai-like<0.3.0,>=0.2.0->llama-index-llms-groq) (23.2)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from transformers<5.0.0,>=4.37.0->llama-index-llms-openai-like<0.3.0,>=0.2.0->llama-index-llms-groq) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from transformers<5.0.0,>=4.37.0->llama-index-llms-openai-like<0.3.0,>=0.2.0->llama-index-llms-groq) (0.19.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.3.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (3.19.0)
# Requirement already satisfied: marshmallow-enum<2.0.0,>=1.5.1 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (1.5.1)
# Requirement already satisfied: anyio in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (3.6.2)
# Requirement already satisfied: httpcore==1.* in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (1.0.5)
# Requirement already satisfied: sniffio in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-groq) (0.14.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from openai<2.0.0,>=1.40.0->llama-index-llms-openai<0.3.0,>=0.2.0->llama-index-llms-openai-like<0.3.0,>=0.2.0->llama-index-llms-groq) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages (from openai<2.0.0,>=1.40.0->llama-index-llms-openai<0.3.0,>=0.2.0->llama-index-llms-openai-like<0.3.0,>=0.2.0->llama-index-llms-groq) (0.5.0)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Error parsing dependencies of keras: [Errno 2] No such file or directory: 'c:\\users\\serkan polat\\appdata\\local\\programs\\python\\python310\\lib\\site-packages\\keras-2.12.0.dist-info\\METADATA'
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\serkan polat\appdata\local\programs\python\python310\lib\site-packages)

# %%
from llama_index.llms.groq import Groq

llama3 = Groq(model="llama-3.1-70b-versatile", api_key=groq_api_key, temperature=0) # llama3-70b-8192

llama3
# Out:
# Groq(callback_manager=<llama_index.core.callbacks.base.CallbackManager object at 0x00000182B01AD4E0>, system_prompt=None, messages_to_prompt=<function messages_to_prompt at 0x00000182D47A9AB0>, completion_to_prompt=<function default_completion_to_prompt at 0x00000182D48E52D0>, output_parser=None, pydantic_program_mode=<PydanticProgramMode.DEFAULT: 'default'>, query_wrapper_prompt=None, model='llama-3.1-70b-versatile', temperature=0.0, max_tokens=None, logprobs=None, top_logprobs=0, additional_kwargs={}, max_retries=3, timeout=60.0, default_headers=None, reuse_client=True, api_key='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', api_base='https://api.groq.com/openai/v1', api_version='', strict=False, context_window=3900, is_chat_model=True, is_function_calling_model=True, tokenizer=None)

# %%
response = llama3.complete("Hey!! Whats up?")

print(response)
# Out:
# Not much, just here and ready to chat. How about you? How's your day going so far?

# %% [markdown]
# ## 2. Define Tools

# %%
def flatten_dict(mapping: dict, prefix="")-> str:
    '''
    Flattens dictionary to string
    Example: 
    Input -> {'name': 'Apple', 'Address': 'CA, US', 'closePrice': 229.9}
    Output ->
    name - Apple
    Address - CA, US
    closePrice - 229.9
    '''
    total_txt = ""
    for key, val in mapping.items():
        if type(val) in [str, float, int]:
            total_txt += f"{prefix}{key} - {val}\n"
        elif isinstance(val, dict):
            total_txt += f"{key}\n"
            total_txt += flatten_dict(val, prefix="\t")
        elif isinstance(val, list):
            if isinstance(val[0], dict):
                total_txt += f"{key}\n"
                for v in val:
                    total_txt += flatten_dict(v, prefix="\t")
            else:
                total_txt += f"{key} - {val}\n"
    return total_txt

# %%
from llama_index.core.tools import FunctionTool
from datetime import date

def company_information(ticker: str) -> dict:
    """Use this tool to retrieve company information like addrress, industry, sector, company officers, business summary, website,
       marketCap, current Price, ebitda, total debt, total revenue, debt-to-equity, etc."""
    
    ticker_obj = yf.Ticker(ticker)
    ticker_info = ticker_obj.get_info()
    
    return flatten_dict(ticker_info)

def summary_of_mutual_fund_holders(ticker: str) -> dict:
    """
    Use this tool to retrieve company's top mutual fund holders. 
    It also returns their percentage of share, stock count and value of holdings.
    """
    ticker_obj = yf.Ticker(ticker)
    
    mf_holders = ticker_obj.get_mutualfund_holders()
    return "\n\n".join([flatten_dict(record) for record in mf_holders.to_dict(orient="records")])

def summary_of_institutional_holders(ticker: str) -> dict:
    """
    Use this tool to retrieve company's top institutional holders. 
    It also returns their percentage of share, stock count and value of holdings.
    """
    ticker_obj = yf.Ticker(ticker)
    
    inst_holders = ticker_obj.get_institutional_holders()
    return "\n\n".join([flatten_dict(record) for record in inst_holders.to_dict(orient="records")])

def stock_grade_updrages_downgrades(ticker: str) -> dict:
    """
    Use this to retrieve grade ratings upgrades and downgrades details of particular stock.
    It'll provide name of firms along with 'To Grade' and 'From Grade' details. Grade date is also provided.
    """
    ticker_obj = yf.Ticker(ticker)
    
    curr_year = date.today().year
    
    upgrades_downgrades = ticker_obj.get_upgrades_downgrades()
    upgrades_downgrades = upgrades_downgrades.loc[upgrades_downgrades.index > f"{curr_year}-01-01"]
    upgrades_downgrades = upgrades_downgrades[upgrades_downgrades["Action"].isin(["up", "down"])]
    
    return "\n\n".join([flatten_dict(record) for record in upgrades_downgrades.to_dict(orient="records")])

def stock_splits_history(ticker: str) -> dict:
    """
    Use this tool to retrieve company's historical stock splits data.
    """
    ticker_obj = yf.Ticker(ticker)
    hist_splits = ticker_obj.get_splits()
    
    return flatten_dict(hist_splits.to_dict())

def stock_news(ticker: str) -> dict:
    """
    Use this to retrieve latest news articles discussing particular stock ticker.
    """
    ticker_obj = yf.Ticker(ticker)
    news_links = ticker_obj.get_news()
    
    for news in news_links:
        if "thumbnail" in news:
            news.pop("thumbnail")
        if "uuid" in news:
            news.pop("uuid")
    
    return "\n\n".join([flatten_dict(news) for news in news_links])


company_information_tool = FunctionTool.from_defaults(fn=company_information)
summary_of_mutual_fund_holders_tool = FunctionTool.from_defaults(fn=summary_of_mutual_fund_holders)
summary_of_institutional_holders_tool = FunctionTool.from_defaults(fn=summary_of_institutional_holders)
stock_grade_updrages_downgrades_tool = FunctionTool.from_defaults(fn=stock_grade_updrages_downgrades)
stock_splits_history_tool = FunctionTool.from_defaults(fn=stock_splits_history)
stock_news_tool = FunctionTool.from_defaults(fn=stock_news)

tools = [
    company_information_tool,
    summary_of_mutual_fund_holders_tool,
    summary_of_institutional_holders_tool,
    stock_grade_updrages_downgrades_tool,
    stock_splits_history_tool,
    stock_news_tool
]

# %%
print(company_information("AAPL"))
# Out:
# address1 - One Apple Park Way
# city - Cupertino
# state - CA
# zip - 95014
# country - United States
# phone - 408 996 1010
# website - https://www.apple.com
# industry - Consumer Electronics
# industryKey - consumer-electronics
# industryDisp - Consumer Electronics
# sector - Technology
# sectorKey - technology
# sectorDisp - Technology
# longBusinessSummary - Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, and HomePod. It also provides AppleCare support and cloud services; and operates various platforms, including the App Store that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts. In addition, the company offers various services, such as Apple Arcade, a game subscription service; Apple Fitness+, a personalized fitness service; Apple Music, which offers users a curated listening experience with on-demand radio stations; Apple News+, a subscription news and magazine service; Apple TV+, which offers exclusive original content; Apple Card, a co-branded credit card; and Apple Pay, a cashless payment service, as well as licenses its intellectual property. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It distributes third-party applications for its products through the App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers, wholesalers, retailers, and resellers. Apple Inc. was founded in 1976 and is headquartered in Cupertino, California.
# fullTimeEmployees - 161000
# companyOfficers
# 	maxAge - 1
# 	name - Mr. Timothy D. Cook
# 	age - 62
# 	title - CEO & Director
# 	yearBorn - 1961
# 	fiscalYear - 2023
# 	totalPay - 16239562
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Mr. Luca  Maestri
# 	age - 60
# 	title - CFO & Senior VP
# 	yearBorn - 1963
# 	fiscalYear - 2023
# 	totalPay - 4612242
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Mr. Jeffrey E. Williams
# 	age - 59
# 	title - Chief Operating Officer
# 	yearBorn - 1964
# 	fiscalYear - 2023
# 	totalPay - 4637585
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Ms. Katherine L. Adams
# 	age - 59
# 	title - Senior VP, General Counsel & Secretary
# 	yearBorn - 1964
# 	fiscalYear - 2023
# 	totalPay - 4618064
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Ms. Deirdre  O'Brien
# 	age - 56
# 	title - Senior Vice President of Retail
# 	yearBorn - 1967
# 	fiscalYear - 2023
# 	totalPay - 4613369
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Mr. Chris  Kondo
# 	title - Senior Director of Corporate Accounting
# 	fiscalYear - 2023
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Mr. James  Wilson
# 	title - Chief Technology Officer
# 	fiscalYear - 2023
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Suhasini  Chandramouli
# 	title - Director of Investor Relations
# 	fiscalYear - 2023
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Mr. Greg  Joswiak
# 	title - Senior Vice President of Worldwide Marketing
# 	fiscalYear - 2023
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Mr. Adrian  Perica
# 	age - 49
# 	title - Head of Corporate Development
# 	yearBorn - 1974
# 	fiscalYear - 2023
# 	exercisedValue - 0
# 	unexercisedValue - 0
# auditRisk - 6
# boardRisk - 1
# compensationRisk - 2
# shareHolderRightsRisk - 1
# overallRisk - 1
# governanceEpochDate - 1725148800
# compensationAsOfEpochDate - 1703980800
# irWebsite - http://investor.apple.com/
# maxAge - 86400
# priceHint - 2
# previousClose - 222.77
# open - 223.595
# dayLow - 221.91
# dayHigh - 224.03
# regularMarketPreviousClose - 222.77
# regularMarketOpen - 223.595
# regularMarketDayLow - 221.91
# regularMarketDayHigh - 224.03
# dividendRate - 1.0
# dividendYield - 0.0045
# exDividendDate - 1723420800
# payoutRatio - 0.1476
# fiveYearAvgDividendYield - 0.66
# beta - 1.24
# trailingPE - 33.917683
# forwardPE - 32.962963
# volume - 35396922
# regularMarketVolume - 35396922
# averageVolume - 57010487
# averageVolume10days - 46963920
# averageDailyVolume10Day - 46963920
# bid - 222.38
# ask - 222.48
# bidSize - 100
# askSize - 200
# marketCap - 3382912221184
# fiftyTwoWeekLow - 164.08
# fiftyTwoWeekHigh - 237.23
# priceToSalesTrailing12Months - 8.773045
# fiftyDayAverage - 223.0882
# twoHundredDayAverage - 195.54555
# trailingAnnualDividendRate - 0.97
# trailingAnnualDividendYield - 0.004354267
# currency - USD
# enterpriseValue - 3422423613440
# profitMargins - 0.26441
# floatShares - 15179810381
# sharesOutstanding - 15204100096
# sharesShort - 135042504
# sharesShortPriorMonth - 117696224
# sharesShortPreviousMonthDate - 1722384000
# dateShortInterest - 1724976000
# sharesPercentSharesOut - 0.0089
# heldPercentInsiders - 0.02703
# heldPercentInstitutions - 0.6088
# shortRatio - 2.67
# shortPercentOfFloat - 0.0089
# impliedSharesOutstanding - 15259400192
# bookValue - 4.382
# priceToBook - 50.7759
# lastFiscalYearEnd - 1696032000
# nextFiscalYearEnd - 1727654400
# mostRecentQuarter - 1719619200
# earningsQuarterlyGrowth - 0.079
# netIncomeToCommon - 101956001792
# trailingEps - 6.56
# forwardEps - 6.75
# pegRatio - 3.67
# lastSplitFactor - 4:1
# lastSplitDate - 1598832000
# enterpriseToRevenue - 8.876
# enterpriseToEbitda - 25.971
# 52WeekChange - 0.25021076
# SandP52WeekChange - 0.26327205
# lastDividendValue - 0.25
# lastDividendDate - 1723420800
# exchange - NMS
# quoteType - EQUITY
# symbol - AAPL
# underlyingSymbol - AAPL
# shortName - Apple Inc.
# longName - Apple Inc.
# firstTradeDateEpochUtc - 345479400
# timeZoneFullName - America/New_York
# timeZoneShortName - EDT
# uuid - 8b10e4ae-9eeb-3684-921a-9ab27e4d87aa
# messageBoardId - finmb_24937
# gmtOffSetMilliseconds - -14400000
# currentPrice - 222.5
# targetHighPrice - 270.81
# targetLowPrice - 165.97
# targetMeanPrice - 217.17
# targetMedianPrice - 219.36
# recommendationMean - 2.0
# recommendationKey - buy
# numberOfAnalystOpinions - 40
# totalCash - 61801000960
# totalCashPerShare - 4.065
# ebitda - 131781001216
# totalDebt - 101304000512
# quickRatio - 0.798
# currentRatio - 0.953
# totalRevenue - 385603010560
# debtToEquity - 151.862
# revenuePerShare - 24.957
# returnOnAssets - 0.22612
# returnOnEquity - 1.60583
# freeCashflow - 86158123008
# operatingCashflow - 113040998400
# earningsGrowth - 0.111
# revenueGrowth - 0.049
# grossMargins - 0.45962003
# ebitdaMargins - 0.34175
# operatingMargins - 0.29556
# financialCurrency - USD
# trailingPegRatio - 2.1354

# %% [markdown]
# ## 3. Define Finance Agent (LLM + Tools)

# %% [markdown]
# <img src="react.png" width=350/>

# %%
from llama_index.core.agent import ReActAgent, FunctionCallingAgentWorker

finance_agent = ReActAgent.from_tools(tools=tools, llm=llama3, verbose=True)

finance_agent

# %%
response = finance_agent.query("What is address of microsoft?")

print(str(response))
# Out:
# > Running step cacdb995-0561-45e6-92f1-3772cb45ffb0. Step input: What is address of microsoft?
# Thought: The current language of the user is: English. I need to use a tool to help me answer the question.
# Action: company_information
# Action Input: {'ticker': 'MSFT'}
# Observation: address1 - One Microsoft Way
# city - Redmond
# state - WA
# zip - 98052-6399
# country - United States
# phone - 425 882 8080
# website - https://www.microsoft.com
# industry - Software - Infrastructure
# industryKey - software-infrastructure
# industryDisp - Software - Infrastructure
# sector - Technology
# sectorKey - technology
# sectorDisp - Technology
# longBusinessSummary - Microsoft Corporation develops and supports software, services, devices and solutions worldwide. The Productivity and Business Processes segment offers office, exchange, SharePoint, Microsoft Teams, office 365 Security and Compliance, Microsoft viva, and Microsoft 365 copilot; and office consumer services, such as Microsoft 365 consumer subscriptions, Office licensed on-premises, and other office services. This segment also provides LinkedIn; and dynamics business solutions, including Dynamics 365, a set of intelligent, cloud-based applications across ERP, CRM, power apps, and power automate; and on-premises ERP and CRM applications. The Intelligent Cloud segment offers server products and cloud services, such as azure and other cloud services; SQL and windows server, visual studio, system center, and related client access licenses, as well as nuance and GitHub; and enterprise services including enterprise support services, industry solutions, and nuance professional services. The More Personal Computing segment offers Windows, including windows OEM licensing and other non-volume licensing of the Windows operating system; Windows commercial comprising volume licensing of the Windows operating system, windows cloud services, and other Windows commercial offerings; patent licensing; and windows Internet of Things; and devices, such as surface, HoloLens, and PC accessories. Additionally, this segment provides gaming, which includes Xbox hardware and content, and first- and third-party content; Xbox game pass and other subscriptions, cloud gaming, advertising, third-party disc royalties, and other cloud services; and search and news advertising, which includes Bing, Microsoft News and Edge, and third-party affiliates. The company sells its products through OEMs, distributors, and resellers; and directly through digital marketplaces, online, and retail stores. The company was founded in 1975 and is headquartered in Redmond, Washington.
# fullTimeEmployees - 228000
# companyOfficers
# 	maxAge - 1
# 	name - Mr. Satya  Nadella
# 	age - 56
# 	title - Chairman & CEO
# 	yearBorn - 1967
# 	fiscalYear - 2023
# 	totalPay - 9276400
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Mr. Bradford L. Smith LCA
# 	age - 64
# 	title - President & Vice Chairman
# 	yearBorn - 1959
# 	fiscalYear - 2023
# 	totalPay - 3591277
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Ms. Amy E. Hood
# 	age - 51
# 	title - Executive VP & CFO
# 	yearBorn - 1972
# 	fiscalYear - 2023
# 	totalPay - 3452196
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Mr. Judson B. Althoff
# 	age - 50
# 	title - Executive VP & Chief Commercial Officer
# 	yearBorn - 1973
# 	fiscalYear - 2023
# 	totalPay - 3355797
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Mr. Christopher David Young
# 	age - 51
# 	title - Executive Vice President of Business Development, Strategy & Ventures
# 	yearBorn - 1972
# 	fiscalYear - 2023
# 	totalPay - 2460507
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Ms. Alice L. Jolla
# 	age - 57
# 	title - Corporate VP & Chief Accounting Officer
# 	yearBorn - 1966
# 	fiscalYear - 2023
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Mr. James Kevin Scott
# 	age - 51
# 	title - Executive VP of AI & CTO
# 	yearBorn - 1972
# 	fiscalYear - 2023
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Brett  Iversen
# 	title - Vice President of Investor Relations
# 	fiscalYear - 2023
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Mr. Hossein  Nowbar
# 	title - Chief Legal Officer
# 	fiscalYear - 2023
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Mr. Frank X. Shaw
# 	title - Chief Communications Officer
# 	fiscalYear - 2023
# 	exercisedValue - 0
# 	unexercisedValue - 0
# auditRisk - 3
# boardRisk - 4
# compensationRisk - 2
# shareHolderRightsRisk - 2
# overallRisk - 1
# governanceEpochDate - 1725148800
# compensationAsOfEpochDate - 1703980800
# irWebsite - http://www.microsoft.com/investor/default.aspx
# maxAge - 86400
# priceHint - 2
# previousClose - 427.0
# open - 425.65
# dayLow - 425.46
# dayHigh - 431.82
# regularMarketPreviousClose - 427.0
# regularMarketOpen - 425.65
# regularMarketDayLow - 425.46
# regularMarketDayHigh - 431.82
# dividendRate - 3.0
# dividendYield - 0.0069999998
# exDividendDate - 1723680000
# payoutRatio - 0.2483
# fiveYearAvgDividendYield - 0.9
# beta - 0.896
# trailingPE - 36.490677
# forwardPE - 31.338428
# volume - 14486498
# regularMarketVolume - 14486498
# averageVolume - 19897782
# averageVolume10days - 18099970
# averageDailyVolume10Day - 18099970
# bid - 430.43
# ask - 430.6
# bidSize - 100
# askSize - 100
# marketCap - 3200592642048
# fiftyTwoWeekLow - 309.45
# fiftyTwoWeekHigh - 468.35
# priceToSalesTrailing12Months - 13.057141
# fiftyDayAverage - 424.5068
# twoHundredDayAverage - 412.47195
# trailingAnnualDividendRate - 3.0
# trailingAnnualDividendYield - 0.007025761
# currency - USD
# enterpriseValue - 3222912892928
# profitMargins - 0.35956
# floatShares - 7422780788
# sharesOutstanding - 7433039872
# sharesShort - 65801156
# sharesShortPriorMonth - 57774674
# sharesShortPreviousMonthDate - 1722384000
# dateShortInterest - 1724976000
# sharesPercentSharesOut - 0.0089
# heldPercentInsiders - 0.00054000004
# heldPercentInstitutions - 0.73737
# shortRatio - 2.99
# shortPercentOfFloat - 0.0089
# impliedSharesOutstanding - 7433039872
# bookValue - 36.115
# priceToBook - 11.922746
# lastFiscalYearEnd - 1719705600
# nextFiscalYearEnd - 1751241600
# mostRecentQuarter - 1719705600
# earningsQuarterlyGrowth - 0.097
# netIncomeToCommon - 88135999488
# trailingEps - 11.8
# forwardEps - 13.74
# pegRatio - 2.75
# lastSplitFactor - 2:1
# lastSplitDate - 1045526400
# enterpriseToRevenue - 13.148
# enterpriseToEbitda - 24.9
# 52WeekChange - 0.3085456
# SandP52WeekChange - 0.26327205
# lastDividendValue - 0.75
# lastDividendDate - 1723680000
# exchange - NMS
# quoteType - EQUITY
# symbol - MSFT
# underlyingSymbol - MSFT
# shortName - Microsoft Corporation
# longName - Microsoft Corporation
# firstTradeDateEpochUtc - 511108200
# timeZoneFullName - America/New_York
# timeZoneShortName - EDT
# uuid - b004b3ec-de24-385e-b2c1-923f10d3fb62
# messageBoardId - finmb_21835
# gmtOffSetMilliseconds - -14400000
# currentPrice - 430.59
# targetHighPrice - 541.62
# targetLowPrice - 397.19
# targetMeanPrice - 448.34
# targetMedianPrice - 451.35
# recommendationMean - 1.7
# recommendationKey - buy
# numberOfAnalystOpinions - 47
# totalCash - 75531001856
# totalCashPerShare - 10.162
# ebitda - 129433001984
# totalDebt - 97851998208
# quickRatio - 1.141
# currentRatio - 1.275
# totalRevenue - 245122007040
# debtToEquity - 36.447
# revenuePerShare - 32.986
# returnOnAssets - 0.14802
# returnOnEquity - 0.37133
# freeCashflow - 56705249280
# operatingCashflow - 118547996672
# earningsGrowth - 0.097
# revenueGrowth - 0.152
# grossMargins - 0.69764
# ebitdaMargins - 0.52804
# operatingMargins - 0.43143
# financialCurrency - USD
# trailingPegRatio - 2.3222
#
# > Running step 66434517-504b-4329-8997-ccbb915b1619. Step input: None
# Thought: I can answer without using any more tools. I'll use the user's language to answer
# Answer: The address of Microsoft is One Microsoft Way, Redmond, WA 98052-6399.
# The address of Microsoft is One Microsoft Way, Redmond, WA 98052-6399.

# %%
response = finance_agent.query("What is last close price of microsoft?")

print(str(response))
# Out:
# > Running step 5925f94e-e01e-4cb7-bb34-2d2d60236ef3. Step input: What is last close price of microsoft?
# Thought: The current language of the user is: English. I need to use a tool to help me answer the question.
# Action: company_information
# Action Input: {'ticker': 'MSFT'}
# Observation: address1 - One Microsoft Way
# city - Redmond
# state - WA
# zip - 98052-6399
# country - United States
# phone - 425 882 8080
# website - https://www.microsoft.com
# industry - Software - Infrastructure
# industryKey - software-infrastructure
# industryDisp - Software - Infrastructure
# sector - Technology
# sectorKey - technology
# sectorDisp - Technology
# longBusinessSummary - Microsoft Corporation develops and supports software, services, devices and solutions worldwide. The Productivity and Business Processes segment offers office, exchange, SharePoint, Microsoft Teams, office 365 Security and Compliance, Microsoft viva, and Microsoft 365 copilot; and office consumer services, such as Microsoft 365 consumer subscriptions, Office licensed on-premises, and other office services. This segment also provides LinkedIn; and dynamics business solutions, including Dynamics 365, a set of intelligent, cloud-based applications across ERP, CRM, power apps, and power automate; and on-premises ERP and CRM applications. The Intelligent Cloud segment offers server products and cloud services, such as azure and other cloud services; SQL and windows server, visual studio, system center, and related client access licenses, as well as nuance and GitHub; and enterprise services including enterprise support services, industry solutions, and nuance professional services. The More Personal Computing segment offers Windows, including windows OEM licensing and other non-volume licensing of the Windows operating system; Windows commercial comprising volume licensing of the Windows operating system, windows cloud services, and other Windows commercial offerings; patent licensing; and windows Internet of Things; and devices, such as surface, HoloLens, and PC accessories. Additionally, this segment provides gaming, which includes Xbox hardware and content, and first- and third-party content; Xbox game pass and other subscriptions, cloud gaming, advertising, third-party disc royalties, and other cloud services; and search and news advertising, which includes Bing, Microsoft News and Edge, and third-party affiliates. The company sells its products through OEMs, distributors, and resellers; and directly through digital marketplaces, online, and retail stores. The company was founded in 1975 and is headquartered in Redmond, Washington.
# fullTimeEmployees - 228000
# companyOfficers
# 	maxAge - 1
# 	name - Mr. Satya  Nadella
# 	age - 56
# 	title - Chairman & CEO
# 	yearBorn - 1967
# 	fiscalYear - 2023
# 	totalPay - 9276400
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Mr. Bradford L. Smith LCA
# 	age - 64
# 	title - President & Vice Chairman
# 	yearBorn - 1959
# 	fiscalYear - 2023
# 	totalPay - 3591277
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Ms. Amy E. Hood
# 	age - 51
# 	title - Executive VP & CFO
# 	yearBorn - 1972
# 	fiscalYear - 2023
# 	totalPay - 3452196
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Mr. Judson B. Althoff
# 	age - 50
# 	title - Executive VP & Chief Commercial Officer
# 	yearBorn - 1973
# 	fiscalYear - 2023
# 	totalPay - 3355797
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Mr. Christopher David Young
# 	age - 51
# 	title - Executive Vice President of Business Development, Strategy & Ventures
# 	yearBorn - 1972
# 	fiscalYear - 2023
# 	totalPay - 2460507
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Ms. Alice L. Jolla
# 	age - 57
# 	title - Corporate VP & Chief Accounting Officer
# 	yearBorn - 1966
# 	fiscalYear - 2023
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Mr. James Kevin Scott
# 	age - 51
# 	title - Executive VP of AI & CTO
# 	yearBorn - 1972
# 	fiscalYear - 2023
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Brett  Iversen
# 	title - Vice President of Investor Relations
# 	fiscalYear - 2023
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Mr. Hossein  Nowbar
# 	title - Chief Legal Officer
# 	fiscalYear - 2023
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Mr. Frank X. Shaw
# 	title - Chief Communications Officer
# 	fiscalYear - 2023
# 	exercisedValue - 0
# 	unexercisedValue - 0
# auditRisk - 3
# boardRisk - 4
# compensationRisk - 2
# shareHolderRightsRisk - 2
# overallRisk - 1
# governanceEpochDate - 1725148800
# compensationAsOfEpochDate - 1703980800
# irWebsite - http://www.microsoft.com/investor/default.aspx
# maxAge - 86400
# priceHint - 2
# previousClose - 427.0
# open - 425.65
# dayLow - 425.46
# dayHigh - 431.82
# regularMarketPreviousClose - 427.0
# regularMarketOpen - 425.65
# regularMarketDayLow - 425.46
# regularMarketDayHigh - 431.82
# dividendRate - 3.0
# dividendYield - 0.0069999998
# exDividendDate - 1723680000
# payoutRatio - 0.2483
# fiveYearAvgDividendYield - 0.9
# beta - 0.896
# trailingPE - 36.490677
# forwardPE - 31.338428
# volume - 14486498
# regularMarketVolume - 14486498
# averageVolume - 19897782
# averageVolume10days - 18099970
# averageDailyVolume10Day - 18099970
# bid - 430.43
# ask - 430.6
# bidSize - 100
# askSize - 100
# marketCap - 3200592642048
# fiftyTwoWeekLow - 309.45
# fiftyTwoWeekHigh - 468.35
# priceToSalesTrailing12Months - 13.057141
# fiftyDayAverage - 424.5068
# twoHundredDayAverage - 412.47195
# trailingAnnualDividendRate - 3.0
# trailingAnnualDividendYield - 0.007025761
# currency - USD
# enterpriseValue - 3222912892928
# profitMargins - 0.35956
# floatShares - 7422780788
# sharesOutstanding - 7433039872
# sharesShort - 65801156
# sharesShortPriorMonth - 57774674
# sharesShortPreviousMonthDate - 1722384000
# dateShortInterest - 1724976000
# sharesPercentSharesOut - 0.0089
# heldPercentInsiders - 0.00054000004
# heldPercentInstitutions - 0.73737
# shortRatio - 2.99
# shortPercentOfFloat - 0.0089
# impliedSharesOutstanding - 7433039872
# bookValue - 36.115
# priceToBook - 11.922746
# lastFiscalYearEnd - 1719705600
# nextFiscalYearEnd - 1751241600
# mostRecentQuarter - 1719705600
# earningsQuarterlyGrowth - 0.097
# netIncomeToCommon - 88135999488
# trailingEps - 11.8
# forwardEps - 13.74
# pegRatio - 2.75
# lastSplitFactor - 2:1
# lastSplitDate - 1045526400
# enterpriseToRevenue - 13.148
# enterpriseToEbitda - 24.9
# 52WeekChange - 0.3085456
# SandP52WeekChange - 0.26327205
# lastDividendValue - 0.75
# lastDividendDate - 1723680000
# exchange - NMS
# quoteType - EQUITY
# symbol - MSFT
# underlyingSymbol - MSFT
# shortName - Microsoft Corporation
# longName - Microsoft Corporation
# firstTradeDateEpochUtc - 511108200
# timeZoneFullName - America/New_York
# timeZoneShortName - EDT
# uuid - b004b3ec-de24-385e-b2c1-923f10d3fb62
# messageBoardId - finmb_21835
# gmtOffSetMilliseconds - -14400000
# currentPrice - 430.59
# targetHighPrice - 541.62
# targetLowPrice - 397.19
# targetMeanPrice - 448.34
# targetMedianPrice - 451.35
# recommendationMean - 1.7
# recommendationKey - buy
# numberOfAnalystOpinions - 47
# totalCash - 75531001856
# totalCashPerShare - 10.162
# ebitda - 129433001984
# totalDebt - 97851998208
# quickRatio - 1.141
# currentRatio - 1.275
# totalRevenue - 245122007040
# debtToEquity - 36.447
# revenuePerShare - 32.986
# returnOnAssets - 0.14802
# returnOnEquity - 0.37133
# freeCashflow - 56705249280
# operatingCashflow - 118547996672
# earningsGrowth - 0.097
# revenueGrowth - 0.152
# grossMargins - 0.69764
# ebitdaMargins - 0.52804
# operatingMargins - 0.43143
# financialCurrency - USD
# trailingPegRatio - 2.3222
#
# > Running step e7dec8cd-9a68-4cbe-9139-bb9aa2263b90. Step input: None
# Thought: I can answer without using any more tools. I'll use the user's language to answer
# Answer: The last close price of Microsoft is 427.0
# The last close price of Microsoft is 427.0

# %%
response = finance_agent.query("What is dividend yield for apple stock?")

print(str(response))
# Out:
# > Running step 5f36d7cc-7de8-4a09-9627-4162b1c647fd. Step input: What is dividend yield for apple stock?
# Thought: The current language of the user is: English. I need to use a tool to help me answer the question.
# Action: company_information
# Action Input: {'ticker': 'AAPL'}
# Observation: address1 - One Apple Park Way
# city - Cupertino
# state - CA
# zip - 95014
# country - United States
# phone - 408 996 1010
# website - https://www.apple.com
# industry - Consumer Electronics
# industryKey - consumer-electronics
# industryDisp - Consumer Electronics
# sector - Technology
# sectorKey - technology
# sectorDisp - Technology
# longBusinessSummary - Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, and HomePod. It also provides AppleCare support and cloud services; and operates various platforms, including the App Store that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts. In addition, the company offers various services, such as Apple Arcade, a game subscription service; Apple Fitness+, a personalized fitness service; Apple Music, which offers users a curated listening experience with on-demand radio stations; Apple News+, a subscription news and magazine service; Apple TV+, which offers exclusive original content; Apple Card, a co-branded credit card; and Apple Pay, a cashless payment service, as well as licenses its intellectual property. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It distributes third-party applications for its products through the App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers, wholesalers, retailers, and resellers. Apple Inc. was founded in 1976 and is headquartered in Cupertino, California.
# fullTimeEmployees - 161000
# companyOfficers
# 	maxAge - 1
# 	name - Mr. Timothy D. Cook
# 	age - 62
# 	title - CEO & Director
# 	yearBorn - 1961
# 	fiscalYear - 2023
# 	totalPay - 16239562
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Mr. Luca  Maestri
# 	age - 60
# 	title - CFO & Senior VP
# 	yearBorn - 1963
# 	fiscalYear - 2023
# 	totalPay - 4612242
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Mr. Jeffrey E. Williams
# 	age - 59
# 	title - Chief Operating Officer
# 	yearBorn - 1964
# 	fiscalYear - 2023
# 	totalPay - 4637585
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Ms. Katherine L. Adams
# 	age - 59
# 	title - Senior VP, General Counsel & Secretary
# 	yearBorn - 1964
# 	fiscalYear - 2023
# 	totalPay - 4618064
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Ms. Deirdre  O'Brien
# 	age - 56
# 	title - Senior Vice President of Retail
# 	yearBorn - 1967
# 	fiscalYear - 2023
# 	totalPay - 4613369
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Mr. Chris  Kondo
# 	title - Senior Director of Corporate Accounting
# 	fiscalYear - 2023
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Mr. James  Wilson
# 	title - Chief Technology Officer
# 	fiscalYear - 2023
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Suhasini  Chandramouli
# 	title - Director of Investor Relations
# 	fiscalYear - 2023
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Mr. Greg  Joswiak
# 	title - Senior Vice President of Worldwide Marketing
# 	fiscalYear - 2023
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Mr. Adrian  Perica
# 	age - 49
# 	title - Head of Corporate Development
# 	yearBorn - 1974
# 	fiscalYear - 2023
# 	exercisedValue - 0
# 	unexercisedValue - 0
# auditRisk - 6
# boardRisk - 1
# compensationRisk - 2
# shareHolderRightsRisk - 1
# overallRisk - 1
# governanceEpochDate - 1725148800
# compensationAsOfEpochDate - 1703980800
# irWebsite - http://investor.apple.com/
# maxAge - 86400
# priceHint - 2
# previousClose - 222.77
# open - 223.595
# dayLow - 221.91
# dayHigh - 224.03
# regularMarketPreviousClose - 222.77
# regularMarketOpen - 223.595
# regularMarketDayLow - 221.91
# regularMarketDayHigh - 224.03
# dividendRate - 1.0
# dividendYield - 0.0045
# exDividendDate - 1723420800
# payoutRatio - 0.1476
# fiveYearAvgDividendYield - 0.66
# beta - 1.24
# trailingPE - 33.917683
# forwardPE - 32.962963
# volume - 35396922
# regularMarketVolume - 35396922
# averageVolume - 57010487
# averageVolume10days - 46963920
# averageDailyVolume10Day - 46963920
# bid - 222.38
# ask - 222.48
# bidSize - 100
# askSize - 200
# marketCap - 3382912221184
# fiftyTwoWeekLow - 164.08
# fiftyTwoWeekHigh - 237.23
# priceToSalesTrailing12Months - 8.773045
# fiftyDayAverage - 223.0882
# twoHundredDayAverage - 195.54555
# trailingAnnualDividendRate - 0.97
# trailingAnnualDividendYield - 0.004354267
# currency - USD
# enterpriseValue - 3422423613440
# profitMargins - 0.26441
# floatShares - 15179810381
# sharesOutstanding - 15204100096
# sharesShort - 135042504
# sharesShortPriorMonth - 117696224
# sharesShortPreviousMonthDate - 1722384000
# dateShortInterest - 1724976000
# sharesPercentSharesOut - 0.0089
# heldPercentInsiders - 0.02703
# heldPercentInstitutions - 0.6088
# shortRatio - 2.67
# shortPercentOfFloat - 0.0089
# impliedSharesOutstanding - 15259400192
# bookValue - 4.382
# priceToBook - 50.7759
# lastFiscalYearEnd - 1696032000
# nextFiscalYearEnd - 1727654400
# mostRecentQuarter - 1719619200
# earningsQuarterlyGrowth - 0.079
# netIncomeToCommon - 101956001792
# trailingEps - 6.56
# forwardEps - 6.75
# pegRatio - 3.67
# lastSplitFactor - 4:1
# lastSplitDate - 1598832000
# enterpriseToRevenue - 8.876
# enterpriseToEbitda - 25.971
# 52WeekChange - 0.25021076
# SandP52WeekChange - 0.26327205
# lastDividendValue - 0.25
# lastDividendDate - 1723420800
# exchange - NMS
# quoteType - EQUITY
# symbol - AAPL
# underlyingSymbol - AAPL
# shortName - Apple Inc.
# longName - Apple Inc.
# firstTradeDateEpochUtc - 345479400
# timeZoneFullName - America/New_York
# timeZoneShortName - EDT
# uuid - 8b10e4ae-9eeb-3684-921a-9ab27e4d87aa
# messageBoardId - finmb_24937
# gmtOffSetMilliseconds - -14400000
# currentPrice - 222.5
# targetHighPrice - 270.81
# targetLowPrice - 165.97
# targetMeanPrice - 217.17
# targetMedianPrice - 219.36
# recommendationMean - 2.0
# recommendationKey - buy
# numberOfAnalystOpinions - 40
# totalCash - 61801000960
# totalCashPerShare - 4.065
# ebitda - 131781001216
# totalDebt - 101304000512
# quickRatio - 0.798
# currentRatio - 0.953
# totalRevenue - 385603010560
# debtToEquity - 151.862
# revenuePerShare - 24.957
# returnOnAssets - 0.22612
# returnOnEquity - 1.60583
# freeCashflow - 86158123008
# operatingCashflow - 113040998400
# earningsGrowth - 0.111
# revenueGrowth - 0.049
# grossMargins - 0.45962003
# ebitdaMargins - 0.34175
# operatingMargins - 0.29556
# financialCurrency - USD
# trailingPegRatio - 2.1354
#
# > Running step f5db994b-4333-446b-8da8-b1af73071c80. Step input: None
# Thought: I can answer without using any more tools. I'll use the user's language to answer
# Answer: The dividend yield for Apple stock is 0.0045.
# The dividend yield for Apple stock is 0.0045.

# %%
response = finance_agent.query("What are ebitda, total debt, total revenue and debt-to-equity for Nvidia stock?")

print(str(response))
# Out:
# > Running step 6659944d-de7e-40ab-add9-a174f3086330. Step input: What are ebitda, total debt, total revenue and debt-to-equity for Nvidia stock?
# Thought: The current language of the user is: English. I need to use a tool to help me answer the question.
# Action: company_information
# Action Input: {'ticker': 'NVDA'}
# Observation: address1 - 2788 San Tomas Expressway
# city - Santa Clara
# state - CA
# zip - 95051
# country - United States
# phone - 408 486 2000
# website - https://www.nvidia.com
# industry - Semiconductors
# industryKey - semiconductors
# industryDisp - Semiconductors
# sector - Technology
# sectorKey - technology
# sectorDisp - Technology
# longBusinessSummary - NVIDIA Corporation provides graphics and compute and networking solutions in the United States, Taiwan, China, Hong Kong, and internationally. The Graphics segment offers GeForce GPUs for gaming and PCs, the GeForce NOW game streaming service and related infrastructure, and solutions for gaming platforms; Quadro/NVIDIA RTX GPUs for enterprise workstation graphics; virtual GPU or vGPU software for cloud-based visual and virtual computing; automotive platforms for infotainment systems; and Omniverse software for building and operating metaverse and 3D internet applications. The Compute & Networking segment comprises Data Center computing platforms and end-to-end networking platforms, including Quantum for InfiniBand and Spectrum for Ethernet; NVIDIA DRIVE automated-driving platform and automotive development agreements; Jetson robotics and other embedded platforms; NVIDIA AI Enterprise and other software; and DGX Cloud software and services. The company's products are used in gaming, professional visualization, data center, and automotive markets. It sells its products to original equipment manufacturers, original device manufacturers, system integrators and distributors, independent software vendors, cloud service providers, consumer internet companies, add-in board manufacturers, distributors, automotive manufacturers and tier-1 automotive suppliers, and other ecosystem participants. NVIDIA Corporation was incorporated in 1993 and is headquartered in Santa Clara, California.
# fullTimeEmployees - 29600
# companyOfficers
# 	maxAge - 1
# 	name - Mr. Jen-Hsun  Huang
# 	age - 60
# 	title - Co-Founder, CEO, President & Director
# 	yearBorn - 1963
# 	fiscalYear - 2024
# 	totalPay - 7491487
# 	exercisedValue - 217327152
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Ms. Colette M. Kress
# 	age - 56
# 	title - Executive VP & CFO
# 	yearBorn - 1967
# 	fiscalYear - 2024
# 	totalPay - 1510765
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Ms. Debora  Shoquist
# 	age - 68
# 	title - Executive Vice President of Operations
# 	yearBorn - 1955
# 	fiscalYear - 2024
# 	totalPay - 1371266
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Mr. Timothy S. Teter
# 	age - 56
# 	title - Executive VP, General Counsel & Secretary
# 	yearBorn - 1967
# 	fiscalYear - 2024
# 	totalPay - 1360939
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Mr. Ajay K. Puri
# 	age - 68
# 	title - Executive Vice President of Worldwide Field Operations
# 	yearBorn - 1955
# 	fiscalYear - 2024
# 	totalPay - 2295097
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Mr. Chris A. Malachowsky
# 	title - Co-Founder
# 	fiscalYear - 2024
# 	totalPay - 320000
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Mr. Donald F. Robertson Jr.
# 	age - 54
# 	title - VP & Chief Accounting Officer
# 	yearBorn - 1969
# 	fiscalYear - 2024
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Prof. William J. Dally Ph.D.
# 	age - 62
# 	title - Chief Scientist & Senior VP of Research
# 	yearBorn - 1961
# 	fiscalYear - 2024
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Ms. Mylene  Mangalindan
# 	title - VP of Corporate Communications
# 	fiscalYear - 2024
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Mr. Tommy  Lee
# 	title - Senior Vice President of Systems Engineering & Application
# 	fiscalYear - 2024
# 	exercisedValue - 0
# 	unexercisedValue - 0
# auditRisk - 7
# boardRisk - 10
# compensationRisk - 4
# shareHolderRightsRisk - 6
# overallRisk - 8
# governanceEpochDate - 1725148800
# compensationAsOfEpochDate - 1735603200
# irWebsite - http://phx.corporate-ir.net/phoenix.zhtml?c=116466&p=irol-IRHome
# maxAge - 86400
# priceHint - 2
# previousClose - 119.14
# open - 119.01
# dayLow - 117.6
# dayHigh - 119.955
# regularMarketPreviousClose - 119.14
# regularMarketOpen - 119.01
# regularMarketDayLow - 117.6
# regularMarketDayHigh - 119.955
# dividendRate - 0.04
# dividendYield - 0.00029999999
# exDividendDate - 1726099200
# payoutRatio - 0.010299999
# fiveYearAvgDividendYield - 0.1
# beta - 1.673
# trailingPE - 55.91549
# forwardPE - 32.809917
# volume - 236533725
# regularMarketVolume - 236533725
# averageVolume - 342877543
# averageVolume10days - 349234760
# averageDailyVolume10Day - 349234760
# bid - 119.02
# ask - 119.08
# bidSize - 100
# askSize - 500
# marketCap - 2921523052544
# fiftyTwoWeekLow - 39.23
# fiftyTwoWeekHigh - 140.76
# priceToSalesTrailing12Months - 30.33552
# fiftyDayAverage - 117.5496
# twoHundredDayAverage - 90.73849
# trailingAnnualDividendRate - 0.022
# trailingAnnualDividendYield - 0.0001846567
# currency - USD
# enterpriseValue - 2896738123776
# profitMargins - 0.55041003
# floatShares - 23538988000
# sharesOutstanding - 24529999872
# sharesShort - 260873913
# sharesShortPriorMonth - 275196949
# sharesShortPreviousMonthDate - 1722384000
# dateShortInterest - 1724976000
# sharesPercentSharesOut - 0.0106
# heldPercentInsiders - 0.04298
# heldPercentInstitutions - 0.66876
# shortRatio - 0.69
# shortPercentOfFloat - 0.0111
# impliedSharesOutstanding - 25579499520
# bookValue - 2.368
# priceToBook - 50.29561
# lastFiscalYearEnd - 1706400000
# nextFiscalYearEnd - 1738022400
# mostRecentQuarter - 1722124800
# earningsQuarterlyGrowth - 1.682
# netIncomeToCommon - 53007998976
# trailingEps - 2.13
# forwardEps - 3.63
# pegRatio - 0.98
# lastSplitFactor - 10:1
# lastSplitDate - 1717977600
# enterpriseToRevenue - 30.078
# enterpriseToEbitda - 47.345
# 52WeekChange - 1.7089114
# SandP52WeekChange - 0.26327205
# lastDividendValue - 0.01
# lastDividendDate - 1726099200
# exchange - NMS
# quoteType - EQUITY
# symbol - NVDA
# underlyingSymbol - NVDA
# shortName - NVIDIA Corporation
# longName - NVIDIA Corporation
# firstTradeDateEpochUtc - 917015400
# timeZoneFullName - America/New_York
# timeZoneShortName - EDT
# uuid - 7f5f6a07-b148-30f4-98a2-2caa3df2aed0
# messageBoardId - finmb_32307
# gmtOffSetMilliseconds - -14400000
# currentPrice - 119.1
# targetHighPrice - 180.54
# targetLowPrice - 50.56
# targetMeanPrice - 131.09
# targetMedianPrice - 135.41
# recommendationMean - 1.8
# recommendationKey - buy
# numberOfAnalystOpinions - 50
# totalCash - 34800001024
# totalCashPerShare - 1.419
# ebitda - 61184000000
# totalDebt - 10014999552
# quickRatio - 3.503
# currentRatio - 4.269
# totalRevenue - 96307003392
# debtToEquity - 17.221
# revenuePerShare - 3.91
# returnOnAssets - 0.55258
# returnOnEquity - 1.23767
# freeCashflow - 33725874176
# operatingCashflow - 48663998464
# earningsGrowth - 1.68
# revenueGrowth - 1.224
# grossMargins - 0.75975996
# ebitdaMargins - 0.6353
# operatingMargins - 0.62057
# financialCurrency - USD
# trailingPegRatio - 1.2805
#
# > Running step 9f0ee429-7184-4f29-be76-3677de47ae14. Step input: None
# Thought: I can answer without using any more tools. I'll use the user's language to answer
# Answer: The ebitda for Nvidia stock is 61184000000, total debt is 10014999552, total revenue is 96307003392 and debt-to-equity is 17.221.
# The ebitda for Nvidia stock is 61184000000, total debt is 10014999552, total revenue is 96307003392 and debt-to-equity is 17.221.

# %%
response = finance_agent.query("Summarize Key people at apple.")

print(str(response))
# Out:
# > Running step 1d87b948-b3cd-4ef9-9771-59ee213a2279. Step input: Summarize Key people at apple.
# Thought: The current language of the user is: English. I need to use a tool to help me answer the question.
# Action: company_information
# Action Input: {'ticker': 'AAPL'}
# Observation: address1 - One Apple Park Way
# city - Cupertino
# state - CA
# zip - 95014
# country - United States
# phone - 408 996 1010
# website - https://www.apple.com
# industry - Consumer Electronics
# industryKey - consumer-electronics
# industryDisp - Consumer Electronics
# sector - Technology
# sectorKey - technology
# sectorDisp - Technology
# longBusinessSummary - Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, and HomePod. It also provides AppleCare support and cloud services; and operates various platforms, including the App Store that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts. In addition, the company offers various services, such as Apple Arcade, a game subscription service; Apple Fitness+, a personalized fitness service; Apple Music, which offers users a curated listening experience with on-demand radio stations; Apple News+, a subscription news and magazine service; Apple TV+, which offers exclusive original content; Apple Card, a co-branded credit card; and Apple Pay, a cashless payment service, as well as licenses its intellectual property. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It distributes third-party applications for its products through the App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers, wholesalers, retailers, and resellers. Apple Inc. was founded in 1976 and is headquartered in Cupertino, California.
# fullTimeEmployees - 161000
# companyOfficers
# 	maxAge - 1
# 	name - Mr. Timothy D. Cook
# 	age - 62
# 	title - CEO & Director
# 	yearBorn - 1961
# 	fiscalYear - 2023
# 	totalPay - 16239562
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Mr. Luca  Maestri
# 	age - 60
# 	title - CFO & Senior VP
# 	yearBorn - 1963
# 	fiscalYear - 2023
# 	totalPay - 4612242
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Mr. Jeffrey E. Williams
# 	age - 59
# 	title - Chief Operating Officer
# 	yearBorn - 1964
# 	fiscalYear - 2023
# 	totalPay - 4637585
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Ms. Katherine L. Adams
# 	age - 59
# 	title - Senior VP, General Counsel & Secretary
# 	yearBorn - 1964
# 	fiscalYear - 2023
# 	totalPay - 4618064
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Ms. Deirdre  O'Brien
# 	age - 56
# 	title - Senior Vice President of Retail
# 	yearBorn - 1967
# 	fiscalYear - 2023
# 	totalPay - 4613369
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Mr. Chris  Kondo
# 	title - Senior Director of Corporate Accounting
# 	fiscalYear - 2023
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Mr. James  Wilson
# 	title - Chief Technology Officer
# 	fiscalYear - 2023
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Suhasini  Chandramouli
# 	title - Director of Investor Relations
# 	fiscalYear - 2023
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Mr. Greg  Joswiak
# 	title - Senior Vice President of Worldwide Marketing
# 	fiscalYear - 2023
# 	exercisedValue - 0
# 	unexercisedValue - 0
# 	maxAge - 1
# 	name - Mr. Adrian  Perica
# 	age - 49
# 	title - Head of Corporate Development
# 	yearBorn - 1974
# 	fiscalYear - 2023
# 	exercisedValue - 0
# 	unexercisedValue - 0
# auditRisk - 6
# boardRisk - 1
# compensationRisk - 2
# shareHolderRightsRisk - 1
# overallRisk - 1
# governanceEpochDate - 1725148800
# compensationAsOfEpochDate - 1703980800
# irWebsite - http://investor.apple.com/
# maxAge - 86400
# priceHint - 2
# previousClose - 222.77
# open - 223.595
# dayLow - 221.91
# dayHigh - 224.03
# regularMarketPreviousClose - 222.77
# regularMarketOpen - 223.595
# regularMarketDayLow - 221.91
# regularMarketDayHigh - 224.03
# dividendRate - 1.0
# dividendYield - 0.0045
# exDividendDate - 1723420800
# payoutRatio - 0.1476
# fiveYearAvgDividendYield - 0.66
# beta - 1.24
# trailingPE - 33.917683
# forwardPE - 32.962963
# volume - 35396922
# regularMarketVolume - 35396922
# averageVolume - 57010487
# averageVolume10days - 46963920
# averageDailyVolume10Day - 46963920
# bid - 222.38
# ask - 222.48
# bidSize - 100
# askSize - 200
# marketCap - 3382912221184
# fiftyTwoWeekLow - 164.08
# fiftyTwoWeekHigh - 237.23
# priceToSalesTrailing12Months - 8.773045
# fiftyDayAverage - 223.0882
# twoHundredDayAverage - 195.54555
# trailingAnnualDividendRate - 0.97
# trailingAnnualDividendYield - 0.004354267
# currency - USD
# enterpriseValue - 3422423613440
# profitMargins - 0.26441
# floatShares - 15179810381
# sharesOutstanding - 15204100096
# sharesShort - 135042504
# sharesShortPriorMonth - 117696224
# sharesShortPreviousMonthDate - 1722384000
# dateShortInterest - 1724976000
# sharesPercentSharesOut - 0.0089
# heldPercentInsiders - 0.02703
# heldPercentInstitutions - 0.6088
# shortRatio - 2.67
# shortPercentOfFloat - 0.0089
# impliedSharesOutstanding - 15259400192
# bookValue - 4.382
# priceToBook - 50.7759
# lastFiscalYearEnd - 1696032000
# nextFiscalYearEnd - 1727654400
# mostRecentQuarter - 1719619200
# earningsQuarterlyGrowth - 0.079
# netIncomeToCommon - 101956001792
# trailingEps - 6.56
# forwardEps - 6.75
# pegRatio - 3.67
# lastSplitFactor - 4:1
# lastSplitDate - 1598832000
# enterpriseToRevenue - 8.876
# enterpriseToEbitda - 25.971
# 52WeekChange - 0.25021076
# SandP52WeekChange - 0.26327205
# lastDividendValue - 0.25
# lastDividendDate - 1723420800
# exchange - NMS
# quoteType - EQUITY
# symbol - AAPL
# underlyingSymbol - AAPL
# shortName - Apple Inc.
# longName - Apple Inc.
# firstTradeDateEpochUtc - 345479400
# timeZoneFullName - America/New_York
# timeZoneShortName - EDT
# uuid - 8b10e4ae-9eeb-3684-921a-9ab27e4d87aa
# messageBoardId - finmb_24937
# gmtOffSetMilliseconds - -14400000
# currentPrice - 222.5
# targetHighPrice - 270.81
# targetLowPrice - 165.97
# targetMeanPrice - 217.17
# targetMedianPrice - 219.36
# recommendationMean - 2.0
# recommendationKey - buy
# numberOfAnalystOpinions - 40
# totalCash - 61801000960
# totalCashPerShare - 4.065
# ebitda - 131781001216
# totalDebt - 101304000512
# quickRatio - 0.798
# currentRatio - 0.953
# totalRevenue - 385603010560
# debtToEquity - 151.862
# revenuePerShare - 24.957
# returnOnAssets - 0.22612
# returnOnEquity - 1.60583
# freeCashflow - 86158123008
# operatingCashflow - 113040998400
# earningsGrowth - 0.111
# revenueGrowth - 0.049
# grossMargins - 0.45962003
# ebitdaMargins - 0.34175
# operatingMargins - 0.29556
# financialCurrency - USD
# trailingPegRatio - 2.1354
#
# > Running step b4522594-259a-4183-91ae-149a83bd7834. Step input: None
# Thought: I can answer without using any more tools. I'll use the user's language to answer
# Answer: The key people at Apple include:
#
# 1. Mr. Timothy D. Cook - CEO & Director
# 2. Mr. Luca Maestri - CFO & Senior VP
# 3. Mr. Jeffrey E. Williams - Chief Operating Officer
# 4. Ms. Katherine L. Adams - Senior VP, General Counsel & Secretary
# 5. Ms. Deirdre O'Brien - Senior Vice President of Retail
# 6. Mr. Chris Kondo - Senior Director of Corporate Accounting
# 7. Mr. James Wilson - Chief Technology Officer
# 8. Suhasini Chandramouli - Director of Investor Relations
# 9. Mr. Greg Joswiak - Senior Vice President of Worldwide Marketing
# 10. Mr. Adrian Perica - Head of Corporate Development
# The key people at Apple include:
#
# 1. Mr. Timothy D. Cook - CEO & Director
# 2. Mr. Luca Maestri - CFO & Senior VP
# 3. Mr. Jeffrey E. Williams - Chief Operating Officer
# 4. Ms. Katherine L. Adams - Senior VP, General Counsel & Secretary
# 5. Ms. Deirdre O'Brien - Senior Vice President of Retail
# 6. Mr. Chris Kondo - Senior Director of Corporate Accounting
# 7. Mr. James Wilson - Chief Technology Officer
# 8. Suhasini Chandramouli - Director of Investor Relations
# 9. Mr. Greg Joswiak - Senior Vice President of Worldwide Marketing
# 10. Mr. Adrian Perica - Head of Corporate Development

# %%
response = finance_agent.query("Top mutual fund holders of microsoft stock. Share list along with their percents.")

print(str(response))
# Out:
# > Running step ab367932-9109-4937-ae60-ab0f7e72d30a. Step input: Top mutual fund holders of microsoft stock. Share list along with their percents.
# Thought: The current language of the user is: English. I need to use a tool to help me answer the question.
# Action: summary_of_mutual_fund_holders
# Action Input: {'ticker': 'MSFT'}
# Observation: Holder - Vanguard Total Stock Market Index Fund
# pctHeld - 0.0312
# Shares - 231883087
# Value - 78965466446
#
#
# Holder - Vanguard 500 Index Fund
# pctHeld - 0.0238
# Shares - 177034936
# Value - 60287477105
#
#
# Holder - Fidelity 500 Index Fund
# pctHeld - 0.0115
# Shares - 85181943
# Value - 27919233637
#
#
# Holder - SPDR S&P 500 ETF Trust
# pctHeld - 0.0112
# Shares - 83514381
# Value - 26369665800
#
#
# Holder - iShares Core S&P 500 ETF
# pctHeld - 0.0095
# Shares - 70264910
# Value - 22186145332
#
#
# Holder - Vanguard Growth Index Fund
# pctHeld - 0.0085
# Shares - 63262454
# Value - 21543396085
#
#
# Holder - Invesco ETF Tr-Invesco QQQ Tr, Series 1 ETF
# pctHeld - 0.007900001
# Shares - 58757680
# Value - 19258417196
#
#
# Holder - Vanguard Institutional Index Fund-Institutional Index Fund
# pctHeld - 0.0068
# Shares - 50756950
# Value - 17284771753
#
#
# Holder - Vanguard Information Technology Index Fund
# pctHeld - 0.0053
# Shares - 39119308
# Value - 12821744390
#
#
# Holder - Growth Fund Of America Inc
# pctHeld - 0.0053
# Shares - 39310503
# Value - 12412291322
#
# > Running step 589555a6-8d8f-4a1d-a15f-354af57a3685. Step input: None
# Thought: I can answer without using any more tools. I'll use the user's language to answer
# Answer: The top mutual fund holders of Microsoft stock are:
#
# 1. Vanguard Total Stock Market Index Fund - 3.12%
# 2. Vanguard 500 Index Fund - 2.38%
# 3. Fidelity 500 Index Fund - 1.15%
# 4. SPDR S&P 500 ETF Trust - 1.12%
# 5. iShares Core S&P 500 ETF - 0.95%
# 6. Vanguard Growth Index Fund - 0.85%
# 7. Invesco ETF Tr-Invesco QQQ Tr, Series 1 ETF - 0.79%
# 8. Vanguard Institutional Index Fund-Institutional Index Fund - 0.68%
# 9. Vanguard Information Technology Index Fund - 0.53%
# 10. Growth Fund Of America Inc - 0.53%
#
# These holders have a significant stake in Microsoft stock, with the top holder, Vanguard Total Stock Market Index Fund, holding 3.12% of the shares.
# The top mutual fund holders of Microsoft stock are:
#
# 1. Vanguard Total Stock Market Index Fund - 3.12%
# 2. Vanguard 500 Index Fund - 2.38%
# 3. Fidelity 500 Index Fund - 1.15%
# 4. SPDR S&P 500 ETF Trust - 1.12%
# 5. iShares Core S&P 500 ETF - 0.95%
# 6. Vanguard Growth Index Fund - 0.85%
# 7. Invesco ETF Tr-Invesco QQQ Tr, Series 1 ETF - 0.79%
# 8. Vanguard Institutional Index Fund-Institutional Index Fund - 0.68%
# 9. Vanguard Information Technology Index Fund - 0.53%
# 10. Growth Fund Of America Inc - 0.53%
#
# These holders have a significant stake in Microsoft stock, with the top holder, Vanguard Total Stock Market Index Fund, holding 3.12% of the shares.

# %%
response = finance_agent.query("Top institutional holders of apple stock and their share.")

print(str(response))
# Out:
# > Running step 71888c67-ccce-42ee-a2a7-a843968f6499. Step input: Top institutional holders of apple stock and their share.
# Thought: The current language of the user is: English. I need to use a tool to help me answer the question.
# Action: summary_of_institutional_holders
# Action Input: {'ticker': 'AAPL'}
# Observation: Holder - Vanguard Group Inc
# pctHeld - 0.0834
# Shares - 1303688506
# Value - 252876459508
#
#
# Holder - Blackrock Inc.
# pctHeld - 0.0665
# Shares - 1039640859
# Value - 201659137420
#
#
# Holder - Berkshire Hathaway, Inc
# pctHeld - 0.0586
# Shares - 915560382
# Value - 177591247296
#
#
# Holder - State Street Corporation
# pctHeld - 0.037
# Shares - 578897858
# Value - 112288817516
#
#
# Holder - FMR, LLC
# pctHeld - 0.0196
# Shares - 307066638
# Value - 59561715772
#
#
# Holder - Geode Capital Management, LLC
# pctHeld - 0.0186
# Shares - 291538165
# Value - 56549657865
#
#
# Holder - Price (T.Rowe) Associates Inc
# pctHeld - 0.0145000005
# Shares - 226650943
# Value - 43963483413
#
#
# Holder - Morgan Stanley
# pctHeld - 0.013099999
# Shares - 204714950
# Value - 39708558851
#
#
# Holder - Norges Bank Investment Management
# pctHeld - 0.0107
# Shares - 167374278
# Value - 21746939940
#
#
# Holder - Northern Trust Corporation
# pctHeld - 0.0105
# Shares - 164536073
# Value - 31915062079
#
# > Running step 041fdc41-6dfe-4926-9a04-53748700904d. Step input: None
# Thought: I can answer without using any more tools. I'll use the user's language to answer
# Answer: The top institutional holders of Apple stock and their share are:
# 1. Vanguard Group Inc - 8.34%
# 2. Blackrock Inc. - 6.65%
# 3. Berkshire Hathaway, Inc - 5.86%
# 4. State Street Corporation - 3.7%
# 5. FMR, LLC - 1.96%
# 6. Geode Capital Management, LLC - 1.86%
# 7. Price (T.Rowe) Associates Inc - 1.45%
# 8. Morgan Stanley - 1.31%
# 9. Norges Bank Investment Management - 1.07%
# 10. Northern Trust Corporation - 1.05%
# The top institutional holders of Apple stock and their share are:
# 1. Vanguard Group Inc - 8.34%
# 2. Blackrock Inc. - 6.65%
# 3. Berkshire Hathaway, Inc - 5.86%
# 4. State Street Corporation - 3.7%
# 5. FMR, LLC - 1.96%
# 6. Geode Capital Management, LLC - 1.86%
# 7. Price (T.Rowe) Associates Inc - 1.45%
# 8. Morgan Stanley - 1.31%
# 9. Norges Bank Investment Management - 1.07%
# 10. Northern Trust Corporation - 1.05%

# %%
response = finance_agent.query("Which firms recently changed grade of apple stock? Also, return rating changes as bullet points.")

print(str(response))
# Out:
# > Running step a22a8987-b434-458a-8718-588f7ef45e06. Step input: Which firms recently changed grade of apple stock? Also, return rating changes as bullet points.
# Thought: The current language of the user is: English. I need to use a tool to help me answer the question.
# Action: stock_grade_updrages_downgrades
# Action Input: {'ticker': 'AAPL'}
# Observation: Firm - Loop Capital
# ToGrade - Buy
# FromGrade - Hold
# Action - up
#
#
# Firm - Rosenblatt
# ToGrade - Buy
# FromGrade - Neutral
# Action - up
#
#
# Firm - Erste Group
# ToGrade - Buy
# FromGrade - Hold
# Action - up
#
#
# Firm - DA Davidson
# ToGrade - Buy
# FromGrade - Neutral
# Action - up
#
#
# Firm - Itau BBA
# ToGrade - Market Perform
# FromGrade - Underperform
# Action - up
#
#
# Firm - Bernstein
# ToGrade - Outperform
# FromGrade - Market Perform
# Action - up
#
#
# Firm - DZ Bank
# ToGrade - Hold
# FromGrade - Buy
# Action - down
#
#
# Firm - B of A Securities
# ToGrade - Buy
# FromGrade - Neutral
# Action - up
#
#
# Firm - Redburn Atlantic
# ToGrade - Neutral
# FromGrade - Buy
# Action - down
#
#
# Firm - Piper Sandler
# ToGrade - Neutral
# FromGrade - Overweight
# Action - down
#
#
# Firm - Barclays
# ToGrade - Underweight
# FromGrade - Equal-Weight
# Action - down
#
# > Running step 6f6fabc8-6703-4427-94c5-2355f930d734. Step input: None
# Thought: I can answer without using any more tools. I'll use the user's language to answer
# Answer: The firms that recently changed the grade of Apple stock are:
#
# * Loop Capital: Upgraded from Hold to Buy
# * Rosenblatt: Upgraded from Neutral to Buy
# * Erste Group: Upgraded from Hold to Buy
# * DA Davidson: Upgraded from Neutral to Buy
# * Itau BBA: Upgraded from Underperform to Market Perform
# * Bernstein: Upgraded from Market Perform to Outperform
# * B of A Securities: Upgraded from Neutral to Buy
#
# The firms that downgraded the grade of Apple stock are:
#
# * DZ Bank: Downgraded from Buy to Hold
# * Redburn Atlantic: Downgraded from Buy to Neutral
# * Piper Sandler: Downgraded from Overweight to Neutral
# * Barclays: Downgraded from Equal-Weight to Underweight
# The firms that recently changed the grade of Apple stock are:
#
# * Loop Capital: Upgraded from Hold to Buy
# * Rosenblatt: Upgraded from Neutral to Buy
# * Erste Group: Upgraded from Hold to Buy
# * DA Davidson: Upgraded from Neutral to Buy
# * Itau BBA: Upgraded from Underperform to Market Perform
# * Bernstein: Upgraded from Market Perform to Outperform
# * B of A Securities: Upgraded from Neutral to Buy
#
# The firms that downgraded the grade of Apple stock are:
#
# * DZ Bank: Downgraded from Buy to Hold
# * Redburn Atlantic: Downgraded from Buy to Neutral
# * Piper Sandler: Downgraded from Overweight to Neutral
# * Barclays: Downgraded from Equal-Weight to Underweight

# %%
response = finance_agent.query("Can you share latest news articles links discussing apple stocks?")

print(str(response))
# Out:
# > Running step 6d81b3c1-35cd-44f1-99da-ff1c8d9ec14d. Step input: Can you share latest news articles links discussing apple stocks?
# Thought: The current language of the user is: English. I need to use a tool to help me answer the question.
# Action: stock_news
# Action Input: {'ticker': 'AAPL'}
# Observation: title - 3 Warren Buffett Stocks to Load Up on Right Now
# publisher - Motley Fool
# link - https://finance.yahoo.com/m/2b3857ae-3a88-3059-9f58-309f333bfa08/3-warren-buffett-stocks-to.html
# providerPublishTime - 1726315200
# type - STORY
# relatedTickers - ['AMZN', 'AAPL', 'ULTA']
#
#
# title - Apple Has a Hot New Product. It’s a Hearing Aid.
# publisher - The Wall Street Journal
# link - https://finance.yahoo.com/m/4aa4bc7b-42ce-3c83-95a5-7531f63e04bc/apple-has-a-hot-new-product..html
# providerPublishTime - 1726275600
# type - STORY
# relatedTickers - ['AAPL']
#
#
# title - Apple (AAPL) Stock Drops Despite Market Gains: Important Facts to Note
# publisher - Zacks
# link - https://finance.yahoo.com/news/apple-aapl-stock-drops-despite-214519779.html
# providerPublishTime - 1726263919
# type - STORY
# relatedTickers - ['AAPL', '^GSPC']
#
#
# title - Apple Begins Taking Preorders For AI-Enabled iPhone 16 Handsets
# publisher - Investor's Business Daily
# link - https://finance.yahoo.com/m/b92b0d3f-72c2-35ce-ad46-c9a1915b22cf/apple-begins-taking-preorders.html
# providerPublishTime - 1726257850
# type - STORY
# relatedTickers - ['AAPL']
#
#
# title - Apple Seeks Dismissal of Lawsuit Against Israeli Cyber Intelligence Firm NSO Group
# publisher - MT Newswires
# link - https://finance.yahoo.com/news/apple-seeks-dismissal-lawsuit-against-174922373.html
# providerPublishTime - 1726249762
# type - STORY
# relatedTickers - ['AAPL']
#
#
# title - FDA Approves OTC Hearing Aid Software Device for Apple AirPods Pro
# publisher - Investopedia
# link - https://finance.yahoo.com/m/501763bd-b8a2-353f-b37c-be2380783f4a/fda-approves-otc-hearing-aid.html
# providerPublishTime - 1726248205
# type - STORY
# relatedTickers - ['AAPL']
#
#
# title - Alternative app stores will be allowed on Apple iPad in the EU from September 16
# publisher - TechCrunch
# link - https://finance.yahoo.com/m/549ea22f-7f66-3ccb-9a29-cd6c091ea746/alternative-app-stores-will.html
# providerPublishTime - 1726246621
# type - STORY
# relatedTickers - ['AAPL']
#
#
# title - iPhone 16 Pre-Orders Start Today—What Investors Need To Know
# publisher - Investopedia
# link - https://finance.yahoo.com/m/0e9c4fb8-bcc6-33dc-99be-6c4ffb2e2783/iphone-16-pre-orders-start.html
# providerPublishTime - 1726245591
# type - STORY
# relatedTickers - ['AAPL']
#
# > Running step 85e7aa60-c977-43c1-a114-8d3c852fd34a. Step input: None
# Thought: I can answer without using any more tools. I'll use the user's language to answer
# Answer: Here are the latest news articles discussing Apple stocks:
#
# 1. 3 Warren Buffett Stocks to Load Up on Right Now - https://finance.yahoo.com/m/2b3857ae-3a88-3059-9f58-309f333bfa08/3-warren-buffett-stocks-to.html
# 2. Apple Has a Hot New Product. It’s a Hearing Aid. - https://finance.yahoo.com/m/4aa4bc7b-42ce-3c83-95a5-7531f63e04bc/apple-has-a-hot-new-product..html
# 3. Apple (AAPL) Stock Drops Despite Market Gains: Important Facts to Note - https://finance.yahoo.com/news/apple-aapl-stock-drops-despite-214519779.html
# 4. Apple Begins Taking Preorders For AI-Enabled iPhone 16 Handsets - https://finance.yahoo.com/m/b92b0d3f-72c2-35ce-ad46-c9a1915b22cf/apple-begins-taking-preorders.html
# 5. Apple Seeks Dismissal of Lawsuit Against Israeli Cyber Intelligence Firm NSO Group - https://finance.yahoo.com/news/apple-seeks-dismissal-lawsuit-against-174922373.html
# 6. FDA Approves OTC Hearing Aid Software Device for Apple AirPods Pro - https://finance.yahoo.com/m/501763bd-b8a2-353f-b37c-be2380783f4a/fda-approves-otc-hearing-aid.html
# 7. Alternative app stores will be allowed on Apple iPad in the EU from September 16 - https://finance.yahoo.com/m/549ea22f-7f66-3ccb-9a29-cd6c091ea746/alternative-app-stores-will.html
# 8. iPhone 16 Pre-Orders Start Today—What Investors Need To Know - https://finance.yahoo.com/m/0e9c4fb8-bcc6-33dc-99be-6c4ffb2e2783/iphone-16-pre-orders-start.html
# Here are the latest news articles discussing Apple stocks:
#
# 1. 3 Warren Buffett Stocks to Load Up on Right Now - https://finance.yahoo.com/m/2b3857ae-3a88-3059-9f58-309f333bfa08/3-warren-buffett-stocks-to.html
# 2. Apple Has a Hot New Product. It’s a Hearing Aid. - https://finance.yahoo.com/m/4aa4bc7b-42ce-3c83-95a5-7531f63e04bc/apple-has-a-hot-new-product..html
# 3. Apple (AAPL) Stock Drops Despite Market Gains: Important Facts to Note - https://finance.yahoo.com/news/apple-aapl-stock-drops-despite-214519779.html
# 4. Apple Begins Taking Preorders For AI-Enabled iPhone 16 Handsets - https://finance.yahoo.com/m/b92b0d3f-72c2-35ce-ad46-c9a1915b22cf/apple-begins-taking-preorders.html
# 5. Apple Seeks Dismissal of Lawsuit Against Israeli Cyber Intelligence Firm NSO Group - https://finance.yahoo.com/news/apple-seeks-dismissal-lawsuit-against-174922373.html
# 6. FDA Approves OTC Hearing Aid Software Device for Apple AirPods Pro - https://finance.yahoo.com/m/501763bd-b8a2-353f-b37c-be2380783f4a/fda-approves-otc-hearing-aid.html
# 7. Alternative app stores will be allowed on Apple iPad in the EU from September 16 - https://finance.yahoo.com/m/549ea22f-7f66-3ccb-9a29-cd6c091ea746/alternative-app-stores-will.html
# 8. iPhone 16 Pre-Orders Start Today—What Investors Need To Know - https://finance.yahoo.com/m/0e9c4fb8-bcc6-33dc-99be-6c4ffb2e2783/iphone-16-pre-orders-start.html
