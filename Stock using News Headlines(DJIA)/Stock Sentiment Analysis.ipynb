# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Stock Headlines.csv', encoding = 'ISO-8859-1')

# %% [markdown]
# # **Exploring the dataset**
# # **Veri kümesini keşfetme**

# %%
df.columns
# Out:
# Index(['Date', 'Label', 'Top1', 'Top2', 'Top3', 'Top4', 'Top5', 'Top6', 'Top7',
#        'Top8', 'Top9', 'Top10', 'Top11', 'Top12', 'Top13', 'Top14', 'Top15',
#        'Top16', 'Top17', 'Top18', 'Top19', 'Top20', 'Top21', 'Top22', 'Top23',
#        'Top24', 'Top25'],
#       dtype='object')

# %%
df.shape
# Out:
# (4101, 27)

# %%
df.head(3)
# Out:
#          Date  Label                                               Top1  \
# 0  2000-01-03      0  A 'hindrance to operations': extracts from the...
# 1  2000-01-04      0                                          Scorecard
# 2  2000-01-05      0                  Coventry caught on counter by Flo
#
#                                  Top2  \
# 0                           Scorecard
# 1                 The best lake scene
# 2  United's rivals on the road to Rio
#
#                                             Top3  \
# 0                Hughes' instant hit buoys Blues
# 1                  Leader: German sleaze inquiry
# 2  Thatcher issues defence before trial by video
#
#                                             Top4  \
# 0       Jack gets his skates on at ice-cold Alex
# 1                                  Cheerio, boyo
# 2  Police help Smith lay down the law at Everton
#
#                                           Top5  \
# 0       Chaos as Maracana builds up for United
# ...

# %% [markdown]
# *Note: Here 'Label' is a binary attribute which consists 0 - Stock
# price goes down or stays the same, 1 - Stock price goes up.*
#
# *Not: Burada 'Etiket', 0'dan oluşan ikili bir niteliktir - Stok
# fiyat düşer veya aynı kalır, 1 - Hisse senedi fiyatı yükselir.*

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Visualizing the count of 'Label' column from the dataset
# Veri kümesinden 'Etiket' sütununun sayısını görselleştirme
plt.figure(figsize=(8,8))
sns.countplot(x='Label', data=df)
plt.xlabel('Stock Sentiments (0-Down/Same, 1-Up)')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # **Data Cleaning and Preprocessing**
# # **Veri Temizleme ve Ön İşleme**

# %%
print(df.shape)
# Out:
# (4101, 27)

# %%
# Finding any NaN values
# Herhangi bir NaN değeri bulma
df.isna().any()
# Out:
# Date     False
# Label    False
# Top1     False
# Top2     False
# Top3     False
# Top4     False
# Top5     False
# Top6     False
# Top7     False
# Top8     False
# Top9     False
# Top10    False
# Top11    False
# Top12    False
# Top13    False
# Top14    False
# Top15    False
# Top16    False
# Top17    False
# Top18    False
# Top19    False
# Top20    False
# Top21    False
# Top22    False
# Top23     True
# Top24     True
# Top25     True
# dtype: bool

# %%
# Dropping NaN values
# NaN değerlerinin düşürülmesi
df.dropna(inplace=True)
print(df.shape)
# Out:
# (4098, 27)

# %%
df_copy = df.copy()

# %%
df_copy.reset_index(inplace=True)

# %%
# Splitting the dataset into train an test set
# Veri setini bir test seti eğitmek için bölme
train = df_copy[df_copy['Date'] < '20150101']
test = df_copy[df_copy['Date'] > '20141231']
print('Train size: {}, Test size: {}'.format(train.shape, test.shape))
# Out:
# Train size: (3972, 28), Test size: (378, 28)

# %%
train.columns
# Out:
# Index(['index', 'Date', 'Label', 'Top1', 'Top2', 'Top3', 'Top4', 'Top5',
#        'Top6', 'Top7', 'Top8', 'Top9', 'Top10', 'Top11', 'Top12', 'Top13',
#        'Top14', 'Top15', 'Top16', 'Top17', 'Top18', 'Top19', 'Top20', 'Top21',
#        'Top22', 'Top23', 'Top24', 'Top25'],
#       dtype='object')

# %%
# Splitting the dataset
# Veri kümesini bölme
y_train = train['Label']
train = train.iloc[:, 3:28]
y_test = test['Label']
test = test.iloc[:, 3:28]

# %%
# Importing essential libraries for performing Natural Language Processing on given dataset
# Verilen veri kümesinde Doğal Dil İşleme gerçekleştirmek için gerekli kitaplıkları içe aktarma
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Serkan
# [nltk_data]     POLAT\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Removing punctuation and special character from the text
# Metinden noktalama işaretlerini ve özel karakterleri kaldırma
train.replace(to_replace='[^a-zA-Z]', value=' ', regex=True, inplace=True)
test.replace(to_replace='[^a-zA-Z]', value=' ', regex=True, inplace=True)

# %%
# Renaming columns
# Sütunları yeniden adlandırma
new_columns = [str(i) for i in range(0,25)]
train.columns = new_columns
test.columns = new_columns

# %%
# Converting the entire text to lower case
# Metnin tamamını küçük harfe dönüştürme
for i in new_columns:
  train[i] = train[i].str.lower()
  test[i] = test[i].str.lower()

# %%
# Joining all the columns
# Tüm sütunları birleştirme
train_headlines = []
test_headlines = []

for row in range(0, train.shape[0]):
  train_headlines.append(' '.join(str(x) for x in train.iloc[row, 0:25]))

for row in range(0, test.shape[0]):
  test_headlines.append(' '.join(str(x) for x in test.iloc[row, 0:25]))

# %%
train_headlines[0]
# Out:
# 'a  hindrance to operations   extracts from the leaked reports scorecard hughes  instant hit buoys blues jack gets his skates on at ice cold alex chaos as maracana builds up for united depleted leicester prevail as elliott spoils everton s party hungry spurs sense rich pickings gunners so wide of an easy target derby raise a glass to strupar s debut double southgate strikes  leeds pay the penalty hammers hand robson a youthful lesson saints party like it s      wear wolves have turned into lambs stump mike catches testy gough s taunt langer escapes to hit     flintoff injury piles on woe for england hunters threaten jospin with new battle of the somme kohl s successor drawn into scandal the difference between men and women sara denver  nurse turned solicitor diana s landmine crusade put tories in a panic yeltsin s resignation caught opposition flat footed russian roulette sold out recovering a title'

# %%
test_headlines[0]
# Out:
# 'most cases of cancer are the result of sheer bad luck rather than unhealthy lifestyles  diet or even inherited genes  new research suggests  random mutations that occur in dna when cells divide are responsible for two thirds of adult cancers across a wide range of tissues  iran dismissed united states efforts to fight islamic state as a ploy to advance u s  policies in the region   the reality is that the united states is not acting to eliminate daesh  they are not even interested in weakening daesh  they are only interested in managing it  poll  one in   germans would join anti muslim marches uk royal family s prince andrew named in us lawsuit over underage sex allegations some    asylum seekers refused to leave the bus when they arrived at their destination in rural northern sweden  demanding that they be taken back to malm or  some big city   pakistani boat blows self up after india navy chase  all four people on board the vessel from near the pakistani port city of karachi are b
# ...

# %%
# Creating corpus of train dataset
# Tren veri kümesi külliyatı oluşturma
ps = PorterStemmer()
train_corpus = []

for i in range(0, len(train_headlines)):
  
  # Tokenizing the news-title by words
  # Haber başlığını kelimelerle belirleme
  words = train_headlines[i].split()

  # Removing the stopwords
    # Engellenecek kelimeleri kaldırma
  words = [word for word in words if word not in set(stopwords.words('english'))]

  # Stemming the words
  # Sözcükleri köklendirmek
  words = [ps.stem(word) for word in words]

  # Joining the stemmed words
  # Köklü kelimelerin birleştirilmesi
  headline = ' '.join(words)

  # Building a corpus of news-title
  # Bir haber başlığı derlemi oluşturmak
  train_corpus.append(headline)

# %%
# Creating corpus of test dataset
# Test veri kümesinin oluşturulması
test_corpus = []

for i in range(0, len(test_headlines)):
  
  # Tokenizing the news-title by words
  # Haber başlığını kelimelerle belirleme
  words = test_headlines[i].split()

  # Removing the stopwords
  # Engellenecek kelimeleri kaldırma
  words = [word for word in words if word not in set(stopwords.words('english'))]

  # Stemming the words
  # Sözcükleri köklendirmek
  words = [ps.stem(word) for word in words]

  # Joining the stemmed words
  # Köklü kelimelerin birleştirilmesi
  headline = ' '.join(words)

  # Building a corpus of news-title
  # Bir haber başlığı derlemi oluşturmak
  test_corpus.append(headline)

# %%
train_corpus[0:10]
# Out:
# ['hindranc oper extract leak report scorecard hugh instant hit buoy blue jack get skate ice cold alex chao maracana build unit deplet leicest prevail elliott spoil everton parti hungri spur sens rich pick gunner wide easi target derbi rais glass strupar debut doubl southgat strike leed pay penalti hammer hand robson youth lesson saint parti like wear wolv turn lamb stump mike catch testi gough taunt langer escap hit flintoff injuri pile woe england hunter threaten jospin new battl somm kohl successor drawn scandal differ men women sara denver nurs turn solicitor diana landmin crusad put tori panic yeltsin resign caught opposit flat foot russian roulett sold recov titl',
# ...

# %%
test_corpus[0:10]
# Out:
# ['case cancer result sheer bad luck rather unhealthi lifestyl diet even inherit gene new research suggest random mutat occur dna cell divid respons two third adult cancer across wide rang tissu iran dismiss unit state effort fight islam state ploy advanc u polici region realiti unit state act elimin daesh even interest weaken daesh interest manag poll one german would join anti muslim march uk royal famili princ andrew name us lawsuit underag sex alleg asylum seeker refus leav bu arriv destin rural northern sweden demand taken back malm big citi pakistani boat blow self india navi chase four peopl board vessel near pakistani port citi karachi believ kill dramat episod arabian sea new year eve accord india defenc ministri sweden hit third mosqu arson attack week car set alight french new year salari top ceo rose twice fast averag canadian sinc recess studi norway violat equal pay law judg say judg find consul employe unjustli paid less male counterpart imam want radic recruit muslim y
# ...

# %%
down_words = []
for i in list(y_train[y_train==0].index):
  down_words.append(train_corpus[i])

up_words = []
for i in list(y_train[y_train==1].index):
  up_words.append(train_corpus[i])

# %%
# Creating wordcloud for down_words
# down_words için kelime bulutu oluşturma
from wordcloud import WordCloud
wordcloud1 = WordCloud(background_color='white', width=3000, height=2500).generate(down_words[1])
plt.figure(figsize=(8,8))
plt.imshow(wordcloud1)
plt.axis('off')
plt.title("Words which indicate a fall in DJIA / DJIA'da düşüşü gösteren kelimeler ")
plt.show()

# %%
# Creating wordcloud for up_words
# up_words için kelime bulutu oluşturma
wordcloud2 = WordCloud(background_color='white', width=3000, height=2500).generate(up_words[5])
plt.figure(figsize=(8,8))
plt.imshow(wordcloud2)
plt.axis('off')
plt.title("Words which indicate a rise in DJIA / DJIA'da yükselişi gösteren kelimeler ")
plt.show()

# %%
# Creating the Bag of Words model
# Bag of Word modelinin oluşturulması
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=10000, ngram_range=(2,2))
X_train = cv.fit_transform(train_corpus).toarray()

# %%
X_test = cv.transform(test_corpus).toarray()

# %% [markdown]
# # **Model Building**
# # **Model Oluşturma**

# %% [markdown]
# ## *Logistic Regression*

# %%
from sklearn.linear_model import LogisticRegression
lr_classifier = LogisticRegression()
lr_classifier.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
lr_y_pred = lr_classifier.predict(X_test)

# %%
# Accuracy, Precision and Recall
# Doğruluk, Kesinlik ve Geri Çağırma
from sklearn.metrics import accuracy_score, precision_score, recall_score
score1 = accuracy_score(y_test, lr_y_pred)
score2 = precision_score(y_test, lr_y_pred)
score3 = recall_score(y_test, lr_y_pred)
print("---- Scores ----")
print("Accuracy score is / Doğruluk puanı: {}%".format(round(score1*100,2)))
print("Precision score is / Kesinlik puanı: {}".format(round(score2,2)))
print("Recall score is / Geri çağırma puanı: {}".format(round(score3,2)))
# Out:
# ---- Scores ----
# Accuracy score is / Doğruluk puanı: 85.98%
# Precision score is / Kesinlik puanı: 0.87
# Recall score is / Geri çağırma puanı: 0.85

# %%
# Making the Confusion Matrix
# Karışıklık Matrisinin Yapılması
from sklearn.metrics import confusion_matrix
lr_cm = confusion_matrix(y_test, lr_y_pred)

# %%
lr_cm
# Out:
# array([[162,  24],
#        [ 29, 163]], dtype=int64)

# %%
# Plotting the confusion matrix
# Karışıklık matrisinin çizilmesi
plt.figure(figsize=(10,7))
sns.heatmap(data=lr_cm, annot=True, cmap="Blues", xticklabels=['Down', 'Up'], yticklabels=['Down', 'Up'])
plt.xlabel('Predicted values / Tahmini değerler')
plt.ylabel('Actual values / Gerçek değerler')
plt.title('Confusion Matrix for Logistic Regression Algorithm / Lojistik Regresyon Algoritması için Karışıklık Matrisi')
plt.show()

# %% [markdown]
# ## *Random Forest Classifier*

# %%
from sklearn.ensemble import RandomForestClassifier
rf_classifier = RandomForestClassifier(n_estimators=100, criterion='entropy')
rf_classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy')

# %%
rf_y_pred = rf_classifier.predict(X_test)

# %%
# Accuracy, Precision and Recall
# Doğruluk, Kesinlik ve Geri Çağırma
score1 = accuracy_score(y_test, rf_y_pred)
score2 = precision_score(y_test, rf_y_pred)
score3 = recall_score(y_test, rf_y_pred)
print("---- Scores ----")
print("Accuracy score is / Doğruluk puanı: {}%".format(round(score1*100,2)))
print("Precision score is / Kesinlik puanı: {}".format(round(score2,2)))
print("Recall score is / Geri çağırma puanı: {}".format(round(score3,2)))
# Out:
# ---- Scores ----
# Accuracy score is / Doğruluk puanı: 84.13%
# Precision score is / Kesinlik puanı: 0.82
# Recall score is / Geri çağırma puanı: 0.88

# %%
# Making the Confusion Matrix
# Karışıklık Matrisinin Yapılması
rf_cm = confusion_matrix(y_test, rf_y_pred)

# %%
rf_cm
# Out:
# array([[149,  37],
#        [ 23, 169]], dtype=int64)

# %%
# Plotting the confusion matrix
# Karışıklık matrisinin çizilmesi
plt.figure(figsize=(10,7))
sns.heatmap(data=rf_cm, annot=True, cmap="Blues", xticklabels=['Down', 'Up'], yticklabels=['Down', 'Up'])
plt.xlabel('Predicted values / Tahmini değerler')
plt.ylabel('Actual values / Gerçek değerler')
plt.title('Confusion Matrix for Random Forest Algorithm / Rastgele Orman Algoritması için Karışıklık Matrisi')
plt.show()

# %% [markdown]
# ## *Multinomial Naive Bayes*

# %%
from sklearn.naive_bayes import MultinomialNB
nb_classifier = MultinomialNB()
nb_classifier.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
# Predicting the Test set results
# Test seti sonuçlarını tahmin etme
nb_y_pred = nb_classifier.predict(X_test)

# %%
# Accuracy, Precision and Recall
score1 = accuracy_score(y_test, nb_y_pred)
score2 = precision_score(y_test, nb_y_pred)
score3 = recall_score(y_test, nb_y_pred)
print("---- Scores ----")
print("Accuracy score is / Doğruluk puanı: {}%".format(round(score1*100,2)))
print("Precision score is / Kesinlik puanı:: {}".format(round(score2,2)))
print("Recall score is / Geri çağırma puanı: {}".format(round(score3,2)))
# Out:
# ---- Scores ----
# Accuracy score is / Doğruluk puanı: 83.86%
# Precision score is / Kesinlik puanı:: 0.85
# Recall score is / Geri çağırma puanı: 0.83

# %%
# Making the Confusion Matrix
# Karışıklık Matrisinin Yapılması
nb_cm = confusion_matrix(y_test, nb_y_pred)

# %%
nb_cm
# Out:
# array([[158,  28],
#        [ 33, 159]], dtype=int64)

# %%
# Plotting the confusion matrix
# Karışıklık matrisinin çizilmesi
plt.figure(figsize=(10,7))
sns.heatmap(data=nb_cm, annot=True, cmap="Blues", xticklabels=['Down', 'Up'], yticklabels=['Down', 'Up'])
plt.xlabel('Predicted values / Tahmini değerler')
plt.ylabel('Actual values / Gerçek değerler')
plt.title('Confusion Matrix for Multinomial Naive Bayes Algorithm / Multinomial Naive Bayes Algoritması için Karışıklık Matrisi')
plt.show()

# %% [markdown]
# # **Predictions**
# # **Tahminler**

# %%
import re

def stock_prediction(sample_news):
  sample_news = re.sub(pattern='[^a-zA-Z]',repl=' ', string=sample_news)
  sample_news = sample_news.lower()
  sample_news_words = sample_news.split()
  sample_news_words = [word for word in sample_news_words if not word in set(stopwords.words('english'))]
  ps = PorterStemmer()
  final_news = [ps.stem(word) for word in sample_news_words]
  final_news = ' '.join(final_news)

  temp = cv.transform([final_news]).toarray()
  return lr_classifier.predict(temp)

# %%
# For generating random integer
# Rastgele tamsayı üretmek için
from random import randint

# %%
sample_test = df_copy[df_copy['Date'] > '20141231']

# %%
sample_test.reset_index(inplace=True)
sample_test = sample_test['Top1']

# %%
# Predicting values
# Tahmin değerleri
row = randint(0,sample_test.shape[0]-1)
sample_news = sample_test[row]

print('News / Haberler:: {}'.format(sample_news))
if stock_prediction(sample_news):
  print('Prediction: The stock price will remain the same or will go down. / Tahmin: Hisse senedi fiyatı aynı kalacak veya düşecek.')
else:
  print('Prediction: The stock price will go up! / Tahmin: Hisse senedi fiyatı yükselecek!')
# Out:
# News / Haberler:: India has slashed prices of 54 essential medicines by up to 55%, including commonly used drugs for cancer, hypertension, diabetes and other heart disorders.
# Prediction: The stock price will remain the same or will go down. / Tahmin: Hisse senedi fiyatı aynı kalacak veya düşecek.

# %%
# Predicting values
# Tahmin değerleri
row = randint(0,sample_test.shape[0]-1)
sample_news = sample_test[row]

print('News / Haberler: {}'.format(sample_news))
if stock_prediction(sample_news):
  print('Prediction: The stock price will remain the same or will go down. / Tahmin: Hisse senedi fiyatı aynı kalacak veya düşecek.')
else:
  print('Prediction: The stock price will go up! / Tahmin: Hisse senedi fiyatı yükselecek!')
# Out:
# News / Haberler: Malawi bans child marriage, lifts minimum age to 18
# Prediction: The stock price will remain the same or will go down. / Tahmin: Hisse senedi fiyatı aynı kalacak veya düşecek.

# %%
# Predicting values
# Tahmin değerleri
row = randint(0,sample_test.shape[0]-1)
sample_news = sample_test[row]

print('News / Haberler: {}'.format(sample_news))
if stock_prediction(sample_news):
  print('Prediction: The stock price will remain the same or will go down. / Tahmin: Hisse senedi fiyatı aynı kalacak veya düşecek.')
else:
  print('Prediction: The stock price will go up! / Tahmin: Hisse senedi fiyatı yükselecek!')
# Out:
# News / Haberler: Puerto Rico says it will default on Monday
# Prediction: The stock price will remain the same or will go down. / Tahmin: Hisse senedi fiyatı aynı kalacak veya düşecek.

# %%
# Predicting values
# Tahmin değerleri
row = randint(0,sample_test.shape[0]-1)
sample_news = sample_test[row]

print('News / Haberler: {}'.format(sample_news))
if stock_prediction(sample_news):
  print('Prediction: The stock price will remain the same or will go down / Tahmin: Hisse senedi fiyatı aynı kalacak veya düşecek.')
else:
  print('Prediction: The stock price will go up! / Tahmin: Hisse senedi fiyatı yükselecek!')
# Out:
# News / Haberler: Mysterious Wooden Idol Found in Russia is 11,000 years old, The Shigir Idol is twice as old as the Pyramids and Stonehenge - and is by far the oldest wooden structure in the world. Covered in a code no one can decipher.
# Prediction: The stock price will go up! / Tahmin: Hisse senedi fiyatı yükselecek!
